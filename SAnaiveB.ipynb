# %%
#Build Your Own Sentiment Analyzer

import pandas as pd     # To handle data
import numpy as np      # For number computing
import csv
import re

# %%
#In order to build a our own sentiment analyzer, first we need to equip ourselves with the right tools and methods. Machine learning is one such tool where
#people have developed various methods to classify. Classifiers may or may not need training data. In particular, we will deal with the Naive Bayes Classifier.

###Preprocess tweets
#start replaceTwoOrMore

def replaceTwoOrMore(s):
    #look for 2 or more repetitions of character
    pattern = re.compile(r"(.)\1{1,}", re.DOTALL) 
    return pattern.sub(r"\1\1", s)

def processTweet2(tweet):
    # process the tweets

    #Convert to lower case
    tweet = tweet.lower()
    #Convert www.* or https?://* to URL
    tweet = re.sub('((www\.[^\s]+)|(https?://[^\s]+))','URL',tweet)
    #Convert @username to AT_USER
    tweet = re.sub('@[^\s]+','AT_USER',tweet)
    #Remove additional white spaces
    tweet = re.sub('[\s]+', ' ', tweet)
    #Replace #word with word
    tweet = re.sub(r'#([^\s]+)', r'\1', tweet)
    #trim
    tweet = tweet.strip('\'"')
    return tweet

# %%
#start getStopWordList
def getStopWordList(stopWordListFileName):
    #read the stopwords
    stopWords = []
    stopWords.append('AT_USER')
    stopWords.append('URL')

    fp = open(stopWordListFileName, 'r')
    line = fp.readline()
    while line:
        word = line.strip()
        stopWords.append(word)
        line = fp.readline()
    fp.close()
    return stopWords

# %%
"""One important step in building a classifier is deciding what features of the input are relevant, and how
to encode those features. For example, we can use the ending letter of the names as a feature and build
a classifier to identify gender with these distinctive features. Specifically, names ending in a, e and i are
likely to be female, while names ending in k, o, r, s and t are likely to be male."""

def getFeatureVector(tweet):
    featureVector = []
    #split tweet into words
    words = tweet.split()
    for w in words:
        #replace two or more with two occurrences
        w = replaceTwoOrMore(w)
        #strip punctuation
        w = w.strip('\'"?,.')
        #check if the word stats with an alphabet
        val = re.search(r"^[a-zA-Z][a-zA-Z0-9]*$", w)
        #ignore if it is a stop word
        if(w in stopWords or val is None):
            continue
        else:
            featureVector.append(w.lower())
    return featureVector

# %%
stopWords = []
stopWords = getStopWordList('/home/ashish/Desktop/FDP_CIT/Python code SA/stopwords.txt')

# %%
#Read the twitter-sanders-apple3 dataset using pandas
import re
df = pd.read_csv("/home/ashish/Desktop/FDP_CIT/Python code SA/twitter-sanders-apple3/twitter-sanders-apple3.csv", encoding ="ISO-8859-1")
df
# Out:
#        class                                               text
# 0        Pos  Now all @Apple has to do is get swype on the i...
# 1        Pos  @Apple will be adding more carrier support to ...
# 2        Pos  Hilarious @youtube video - guy does a duet wit...
# 3        Pos  @RIM you made it too easy for me to switch to ...
# 4        Pos  I just realized that the reason I got into twi...
# 5        Pos  I'm a current @Blackberry user little bit disa...
# 6        Pos  The 16 strangest things Siri has said so far. ...
# 7        Pos  Great up close & personal event @Apple tonight...
# 8        Pos  From which companies do you experience the bes...
# 9        Pos  Just apply for a job at @Apple hope they call ...
# 10       Pos  RT @JamaicanIdler: Lmao I think @apple is onto...
# 11       Pos  Lmao I think @apple is onto something magical!...
# 12       Pos  RT @PhillipRowntree: Just registered as an @ap...
# 13       Pos  Wow. Great deals on refurbed #iPad (first gen)...
# 14       Pos  Just registered as an @apple developer... Here...
# 15       Pos   ! Currently learning Mandarin for my upcoming...
# 16       Pos  Come to the dark side @gretcheneclark: Hey @ap...
# 17       Pos  Hey @apple if you send me a free iPhone (any v...
# 18       Pos  Thank you @apple for Find My Mac - just locate...
# 19       Pos  Thanks to @Apple Covent Garden #GeniusBar for ...
# 20       Pos                     @DailyDealChat @apple Thanks!!
# 21       Pos  iPads Replace Bound Playbooks on Some N.F.L. T...
# 22       Pos                                  @apple..good ipad
# 23       Pos                  @apple @siri is efffing amazing!!
# 24       Pos  Amazing new @Apple iOs 5 feature.  http://t.co...
# 25       Pos  RT @TripLingo: We're one of a few Featured Edu...
# 26       Pos  We're one of a few Featured Education Apps on ...
# 27       Pos  When you want something done right you do it y...
# 28       Pos  We did an unexpected workshop for the #iPhone4...
# 29       Pos                                 &lt;3 #ios5 @apple
# ..       ...                                                ...
# 958  Neutral  Salesperson at #soho @Apple store it doesn't m...
# 959  Neutral  @apple and I'm looking at the outside & all yo...
# 960  Neutral  @samsung and @apple never rest as they battle ...
# 961  Neutral  Iphone update is great but seriously @apple le...
# 962  Neutral  @rjakesuk mine is past the warranty and I don'...
# 963  Neutral  If @Apple could put the USB female connector i...
# 964  Neutral  What do we have to do to get Flash on #iPad? @...
# 965  Neutral  @ireton Perhaps it's time for @Apple to come o...
# 966  Neutral              20 min line @apple store @short pump.
# 967  Neutral  Lol @Apple support playing Mary J Blige during...
# 968  Neutral  RT @TheMacMob: Sprint Verizon & AT&T @Apple St...
# 969  Neutral  @xwordy iCloud was new; I didn't need weather ...
# 970  Neutral  Thinking more I want Android to do an iMessage...
# 971  Neutral  @apple in Austin:  domain location - umbrellas...
# 972  Neutral  bored - need a new intriguing #app for my #iPa...
# 973  Neutral  @KeepnUpWitTBoyd @AppStore @iTunesMusic they f...
# 974  Neutral  And @Apple I still have an old MBP from 2006 w...
# 975  Neutral  @moLifer26 @apple When we find people standing...
# 976  Neutral  ...now with Siri were talking to our iPhones.....
# 977  Neutral  @notleifgarrett @apple you'll be able to affor...
# 978  Neutral  @fabi_m not that I know of. I think it is only...
# 979  Neutral  @notleifgarrett @apple wished their on hold mu...
# 980  Neutral  @RealEstateGuyWI All about yesterday's @Apple ...
# 981  Neutral  after being on hold with @apple for the last 3...
# 982  Neutral  #Win an @Apple iPod Touch from @Mommy_gaga get...
# 983  Neutral  @vlingo is a POOR substitute for Siri!! Yo @AP...
# 984  Neutral                                @Apple Scrapple. (:
# 985  Neutral  @tvnewschick @apple Oh no! Why not?! I want it...
# 986  Neutral  One of the great #entrepreneurs has died. #Ste...
# 987  Neutral  @fashionNOGuilt haha! tomorrow should be less ...
#
# [988 rows x 2 columns]

# %%
# Get tweet words
tweets = []
featureList = []

for i in range(len(df)):
    sentiment = df['class'][i]
    tweet = df['text'][i]
    processedTweet = processTweet2(tweet)
    featureVector = getFeatureVector(processedTweet)
    featureList.extend(featureVector)
    tweets.append((featureVector, sentiment))
tweets
# Out:
# [(['swype', 'iphone', 'crack', 'iphone'], 'Pos'),
#  (['adding', 'carrier', 'support', 'iphone'], 'Pos'),
#  (['hilarious', 'video', 'guy', 'duet', 'siri', 'pretty', 'sums', 'love'],
#   'Pos'),
#  (['easy', 'switch', 'iphone'], 'Pos'),
#  (['realized', 'reason', 'twitter', 'ios5', 'thanks'], 'Pos'),
#  (['current', 'user', 'little', 'bit', 'disappointed', 'move'], 'Pos'),
#  (['strangest', 'siri', 'am', 'soo', 'glad', 'siri', 'sense', 'via'], 'Pos'),
#  (['close', 'personal', 'event', 'tonight', 'regent', 'st'], 'Pos'),
#  (['companies', 'experience', 'customer', 'service', 'aside'], 'Pos'),
#  (['apply', 'job', 'hope', 'call', 'lol'], 'Pos'),
#  (['rt', 'lmao', 'onto', 'am', 'haha', 'siri', 'suggested', 'whores'], 'Pos'),
#  (['lmao',
#    'onto',
#    'am',
#    'haha',
#    'siri',
#    'suggested',
#    'whores',
#    'hide',
#    'body',
#    'lolol'],
#   'Pos'),
#  (['rt', 'registered', 'developer', 'hoping', 'actually', 'help', 'greatly'],
#   'Pos'),
#  (['wow',
#    'deals',
#    'refurbed',
#    'ipad',
#    'models',
#    'apple',
#    'offers',
#    'deals',
#    'refurbished',
#    'ipads'],
#   'Pos'),
#  (['registered', 'developer', 'hoping', 'actually', 'help', 'greatly'], 'Pos'),
#  (['currently',
#    'learning',
#    'mandarin',
#    'upcoming',
#    'trip',
#    'hong',
#    'kong',
#    'gotta',
#    'hand',
#    'iphones',
#    'uber',
#    'useful',
#    'flashcard',
#    'apps'],
#   'Pos'),
#  (['dark',
#    'hey',
#    'send',
#    'free',
#    'iphone',
#    'publicly',
#    'ceremoniously',
#    'burn',
#    'blackberry'],
#   'Pos'),
#  (['hey',
#    'send',
#    'free',
#    'iphone',
#    'version',
#    'publicly',
#    'ceremoniously',
#    'burn',
#    'blackberry'],
#   'Pos'),
#  (['thank',
#    'mac',
#    'located',
#    'wiped',
#    'stolen',
#    'air',
#    'smallvictory',
#    'thievingbastards'],
#   'Pos'),
#  (['thanks',
#    'covent',
#    'garden',
#    'geniusbar',
#    'replacing',
#    'macbook',
#    'wristpad',
#    'lunch',
#    'break',
#    'warranty'],
#   'Pos'),
#  ([], 'Pos'),
#  (['ipads', 'replace', 'bound', 'playbooks', 'teams'], 'Pos'),
#  (['ipad'], 'Pos'),
#  (['effing'], 'Pos'),
#  (['amazing', 'ios', 'feature'], 'Pos'),
#  (['rt', 'featured', 'education', 'apps'], 'Pos'),
#  (['featured', 'education', 'apps'], 'Pos'),
#  (['yourself', 'useless', 'days', 'yourdaysarenumbered'], 'Pos'),
#  (['unexpected',
#    'workshop',
#    'iphone4s',
#    'yesterday',
#    'awesome',
#    'amount',
#    'info',
#    'notjustaboutthephone'],
#   'Pos'),
#  (['ios5'], 'Pos'),
#  (['rt', 'question', 'bro', 'rt', 'dis', 'iphone', 'evo'], 'Pos'),
#  (['rt', 'people', 'bitching', 'iphone4s', 'smartest', 'phone', 'happy'],
#   'Pos'),
#  (['people', 'bitching', 'iphone4s', 'smartest', 'phone', 'happy'], 'Pos'),
#  (['ceo', 'corporate', 'mentor', 'signups', 'triple'], 'Pos'),
#  (['bus', 'iphone', 'thxx'], 'Pos'),
#  (['appstore', 'itunes', 'mobile', 'devices', 'talking', 'desktop', 'app'],
#   'Pos'),
#  (['coach',
#    'bring',
#    'ipad',
#    'ipad',
#    'set',
#    'red',
#    'red',
#    'hut',
#    'hut',
#    'wish',
#    'ipad'],
#   'Pos'),
#  (['apple',
#    'sells',
#    'million',
#    'iphone',
#    'units',
#    'weekend',
#    'steve',
#    'jobs',
#    'brilliance',
#    'lives',
#    'iphone',
#    'rva'],
#   'Pos'),
#  (['apologize'], 'Pos'),
#  (['downloads', 'ios', 'proving', 'popular', 'users'], 'Pos'),
#  (['lmfao', 'look', 'argument', 'siri'], 'Pos'),
#  (['million', 'iphone', 'days', 'iphone', 'iphone4s'], 'Pos'),
#  (['save', 'unwanted', 'help', 'buy', 'seen', 'lol', 'backchannel'], 'Pos'),
#  (['fixed', 'ios5', 'battery', 'drain', 'replacement', 'iphone', 'champ'],
#   'Pos'),
#  (['currently', 'brand', 'macbook', 'bahh', 'macbook', 'miss', 'time'], 'Pos'),
#  (['blessed'], 'Pos'),
#  (['siri', 'dad', 'mom', 'brother', 'girlfriend', 'thanks'], 'Pos'),
#  (['store', 'amazing', 'call', 'waiting', 'need4s'], 'Pos'),
#  (['sweet', 'apple', 'replaced', 'glass', 'probono', 'thank'], 'Pos'),
#  (['sells',
#    'million',
#    'iphones',
#    'debut',
#    'weekend',
#    'bloomberg',
#    'smartphone',
#    'sm',
#    'rt'],
#   'Pos'),
#  (['loving',
#    'technology',
#    'iphone',
#    'mac',
#    'air',
#    'icloud',
#    'unreal',
#    'technology'],
#   'Pos'),
#  (['loving', 'ios5', 'update'], 'Pos'),
#  (['mention', 'apple', 'rt', 'getting', 'customer', 'service', 'store'],
#   'Pos'),
#  (['time',
#    'iphone',
#    'looking',
#    'forward',
#    'sticking',
#    'paying',
#    'texts',
#    'thanks'],
#   'Pos'),
#  (['hey', 'hate', 'computer', 'mack', 'wanna', 'send', 'free'], 'Pos'),
#  (['thank'], 'Pos'),
#  (['icloud', 'set', 'flawless', 'cloud'], 'Pos'),
#  (['totally', 'email', 'company', 'service'], 'Pos'),
#  (['loving', 'ios5', 'upgrade'], 'Pos'),
#  (['nice', 'tech', 'support', 'guy', 'fixed', 'itouch'], 'Pos'),
#  (['getting', 'customer', 'service', 'store', 'millenia', 'mall'], 'Pos'),
#  (['ios5', 'faster', 'ipad'], 'Pos'),
#  (['love', 'imac', 'seen', 'hubby', 'days', 'geek'], 'Pos'),
#  (['switch', 'iphone', 'iphone4s', 'smartphone', 'stevejobs', 'apple'], 'Pos'),
#  (['thankful',
#    'incredible',
#    'people',
#    'beyond',
#    'offering',
#    'replacing',
#    'macbook'],
#   'Pos'),
#  (['play', 'ma', 'loving', 'camera', 'iphone4s', 'fb'], 'Pos'),
#  (['yeah',
#    'ios5',
#    'readinglists',
#    'changed',
#    'life',
#    'nowicanspendevenmoretimeonmyphone'],
#   'Pos'),
#  (['safari', 'reader', 'owns', 'worldwide', 'web'], 'Pos'),
#  (['love', 'service', 'cracked', 'hand', 'walk'], 'Pos'),
#  ([], 'Pos'),
#  (['laid', 'iphone', 'iphone4s'], 'Pos'),
#  (['excited', 'class', 'store', 'buy', 'macosc', 'snow', 'leopard', 'lion'],
#   'Pos'),
#  (['disruptions', 'lost', 'gigs', 'thx', 'service', 'im', 'moving', 'iphone'],
#   'Pos'),
#  (['apple', 'sells', 'million', 'iphones', 'days', 'doing', 'doing', 'doing'],
#   'Pos'),
#  (['lovin',
#    'iphone',
#    'update',
#    'especially',
#    'slide',
#    'bar',
#    'top',
#    'screen',
#    'job'],
#   'Pos'),
#  (['millions', 'weekend', 'iphone4s'], 'Pos'),
#  (['invested', 'macbook', 'pro', 'time', 'selling', 'android', 'gear'], 'Pos'),
#  ([], 'Pos'),
#  (['sent', 'grandma', 'post', 'card', 'using', 'cardsapp', 'thanks'], 'Pos'),
#  (['sorry', 'moving'], 'Pos'),
#  (['putting', 'wash', 'equivalent', 'blend', 'glad', 'hear', 'alive'], 'Pos'),
#  (['laundering',
#    'iphone',
#    'finest',
#    'moment',
#    'drying',
#    'bag',
#    'rice',
#    'days',
#    'booted'],
#   'Pos'),
#  (['bravo'], 'Pos'),
#  (['god',
#    'bless',
#    'appletv',
#    'bad',
#    'ass',
#    'system',
#    'loving',
#    'princessofchina',
#    'gb'],
#   'Pos'),
#  (['twitter', 'days', 'smashed', 'iphone', 'nice'], 'Pos'),
#  (['thank', 'ios', 'email', 'pop', 'lock', 'screen', 'unlocking'], 'Pos'),
#  (['word', 'wow', 'rt', 'iphone', 'weekend', 'sales', 'top'], 'Pos'),
#  (['iphone', 'thanks', 'gods'], 'Pos'),
#  (['rt',
#    'love',
#    'ios5',
#    'easter',
#    'eggs',
#    'pull',
#    'middle',
#    'top',
#    'bottom',
#    'pulls',
#    'awesome',
#    'little',
#    'ios5'],
#   'Pos'),
#  (['love',
#    'ios5',
#    'easter',
#    'eggs',
#    'pull',
#    'middle',
#    'top',
#    'bottom',
#    'pulls',
#    'awesome',
#    'little',
#    'ios5'],
#   'Pos'),
#  (['love',
#    'ios5',
#    'easter',
#    'eggs',
#    'pull',
#    'middle',
#    'top',
#    'bottom',
#    'pulls',
#    'awesome',
#    'little',
#    'lovemyiphone'],
#   'Pos'),
#  (['updated',
#    'ios',
#    'started',
#    'using',
#    'cloud',
#    'services',
#    'pretty',
#    'bad',
#    'ass',
#    'iphone',
#    'champ'],
#   'Pos'),
#  (['gone', 'run', 'beautiful', 'morning', 'love', 'ios', 'iphone'], 'Pos'),
#  (['simply'], 'Pos'),
#  (['admit', 'happy', 'text', 'tones', 'ring', 'makemeproud', 'drakes', 'text'],
#   'Pos'),
#  (['day305',
#    'thankful',
#    'customer',
#    'service',
#    'received',
#    'via',
#    'phone',
#    'cs',
#    'phone'],
#   'Pos'),
#  (['replacing', 'phone', 'free'], 'Pos'),
#  (['loving', 'ipod', 'update'], 'Pos'),
#  (['wife',
#    'upgraded',
#    'iphone',
#    'siri',
#    'worth',
#    'upgrade',
#    'looking',
#    'forward',
#    'continuing',
#    'enhance',
#    'siri'],
#   'Pos'),
#  (['rt', 'thx', 'thx', 'hypo'], 'Pos'),
#  (['honored', 'tonite', 'truly', 'loss', 'missed'], 'Pos'),
#  (['thx', 'thx', 'hypo'], 'Pos'),
#  (['loving', 'iphone4s', 'thanks', 'ios5'], 'Pos'),
#  (['love', 'thank'], 'Pos'),
#  (['iphone', 'genius'], 'Pos'),
#  (['cards',
#    'app',
#    'notifies',
#    'card',
#    'sent',
#    'arrived',
#    'local',
#    'post',
#    'office',
#    'delivered',
#    'sunday',
#    'truly',
#    'magic'],
#   'Pos'),
#  (['love', 'i0s5', 'updates', 'somehow', 'simplifies', 'life', 'apple'],
#   'Pos'),
#  (['siri', 'amazing'], 'Pos'),
#  (['iphone4s'], 'Pos'),
#  (['meet', 'siri', 'iphone', 'butler', 'click', 'link', 'amazed'], 'Pos'),
#  (['am', 'using', 'pc', 'feel', 'worst', 'speakers', 'spoiled', 'imamac'],
#   'Pos'),
#  ([], 'Pos'),
#  (['ios5', 'upgrade', 'luck', 'surviving'], 'Pos'),
#  (['loving', 'ios5', 'awesome'], 'Pos'),
#  (['rt', 'iphone', 'addicted'], 'Pos'),
#  (['thank',
#    'innovations',
#    'exhibit',
#    'guy',
#    'playing',
#    'facetime',
#    'instead',
#    'watching',
#    'game',
#    'sports',
#    'bar'],
#   'Pos'),
#  (['boo', 'berry', 'powered', 'technology', 'actually'], 'Pos'),
#  (['ipod', 'time', 'iphone', 'job', 'guys'], 'Pos'),
#  (['thank', 'steve', 'store', 'av'], 'Pos'),
#  (['siri', 'witchcraft', 'yr', 'lead', 'lost'], 'Pos'),
#  (['ios',
#    'notifications',
#    'phone',
#    'search',
#    'covers',
#    'mail',
#    'wifi',
#    'sync',
#    'icloud',
#    'backup',
#    'integrated',
#    'twitter'],
#   'Pos'),
#  (['rt',
#    'james',
#    'stewart',
#    'story',
#    'ny',
#    'times',
#    'importance',
#    'architecture',
#    'retail',
#    'success'],
#   'Pos'),
#  (['james',
#    'stewart',
#    'story',
#    'ny',
#    'times',
#    'importance',
#    'architecture',
#    'retail',
#    'success'],
#   'Pos'),
#  ([], 'Pos'),
#  (['welcome', 'twitter', 'world', 'due', 'ios5', 'thanks', 'guys'], 'Pos'),
#  (['impressive',
#    'service',
#    'genius',
#    'bar',
#    'metro',
#    'centre',
#    'power',
#    'cable',
#    'replaced',
#    'free',
#    'booked',
#    'screen',
#    'replacement',
#    'free'],
#   'Pos'),
#  (['rt',
#    'nice',
#    'guy',
#    'store',
#    'replaced',
#    'phone',
#    'gratis',
#    'hairline',
#    'crack',
#    'screen',
#    'thanks'],
#   'Pos'),
#  (['nice',
#    'guy',
#    'store',
#    'replaced',
#    'phone',
#    'gratis',
#    'hairline',
#    'crack',
#    'screen',
#    'thanks'],
#   'Pos'),
#  (['iphone',
#    'battery',
#    'lasted',
#    'day',
#    'happened',
#    'edge',
#    'iphone',
#    'nice',
#    'job'],
#   'Pos'),
#  (['mins', 'write', 'blackberry', 'thank', 'converting', 'grass'], 'Pos'),
#  (['rt', 'backside', 'eye', 'impressed'], 'Pos'),
#  (['backside', 'eye', 'impressed'], 'Pos'),
#  (['iphone',
#    'space',
#    'amazing',
#    'creative',
#    'products',
#    'inspire',
#    'people',
#    'unbelievable'],
#   'Pos'),
#  (['thank', 'ipad', 'feel', 'ios'], 'Pos'),
#  (['ipad', 'briliant', 'stevejobs', 'produck'], 'Pos'),
#  (['using', 'awsome', 'ipad', 'love', 'love', 'macbook', 'ipod', 'love'],
#   'Pos'),
#  (['ios', 'upgrade', 'feature', 'feature', 'required'], 'Pos'),
#  (['ios', 'update', 'iloveyou'], 'Pos'),
#  (['finally', 'iphone', 'thanks', 'stupid', 'learned', 'lesson'], 'Pos'),
#  (['absolutely', 'love', 'iphone', 'thank', 'steve'], 'Pos'),
#  (['invented',
#    'product',
#    'actually',
#    'brother',
#    'call',
#    'parents',
#    'amazing',
#    'siri',
#    'ipod4s'],
#   'Pos'),
#  (['dammit', 'listening', 'siri', 'upgrade', 'played'], 'Pos'),
#  (['create',
#    'folders',
#    'photo',
#    'album',
#    'ios5',
#    'thanks',
#    'thorn',
#    'newfeature'],
#   'Pos'),
#  (['video', 'card', 'workstation', 'died', 'six', 'months', 'hello'], 'Pos'),
#  (['throw', 'trash', 'upload'], 'Pos'),
#  (['ios5', 'update', 'submitted', 'thanks'], 'Pos'),
#  (['awesome', 'service', 'store', 'pc', 'thanks'], 'Pos'),
#  (['rt', 'thanks', 'fixing'], 'Pos'),
#  (['am', 'crazy', 'ios5', 'photo', 'cropping'], 'Pos'),
#  (['thanks', 'fixing'], 'Pos'),
#  (['hell', 'contacts', 'thanks'], 'Pos'),
#  (['rt', 'love', 'phone', 'siri'], 'Pos'),
#  (['changed', 'life'], 'Pos'),
#  (['mad', 'props', 'employee', 'charge', 'replace', 'plate'], 'Pos'),
#  (['actually', 'mouse', 'pretty', 'sweet'], 'Pos'),
#  (['iphone4s',
#    'amazing',
#    'voice',
#    'recognition',
#    'absolutely',
#    'step',
#    'previous',
#    'attempts',
#    'bravo'],
#   'Pos'),
#  (['finally', 'iphone', 'thanks', 'getting', 'times'], 'Pos'),
#  (['ios5', 'nice', 'thanks'], 'Pos'),
#  (['support', 'fm', 'kevin', 'bellevue', 'store', 'biz', 'customers'], 'Pos'),
#  (['downloaded', 'ios', 'thankyou'], 'Pos'),
#  (['wow', 'am', 'loving', 'update', 'touch', 'coolness'], 'Pos'),
#  (['siri'], 'Pos'),
#  (['love', 'love', 'love', 'ios'], 'Pos'),
#  (['rt',
#    'apparently',
#    'mb',
#    'cap',
#    'sms',
#    'update',
#    'storage',
#    'tells',
#    'inbox'],
#   'Neg'),
#  (['rt', 'iphones', 'expensive', 'customer', 'loyalty', 'comp'], 'Neg'),
#  (['iphones', 'expensive', 'customer', 'loyalty', 'comp'], 'Neg'),
#  (['kill', 'apple', 'rip'], 'Neg'),
#  (['tunes', 'iphone', 'iphone', 'lonely', 'silly', 'ios5'], 'Neg'),
#  (['hurry', 'release', 'itunesmatch'], 'Neg'),
#  (['siri'], 'Neg'),
#  (['exchange', 'cord', 'apple', 'store', 'wait', 'genius'], 'Neg'),
#  (['airdrop', 'fail', 'immediate', 'declined', 'request', 'time'], 'Neg'),
#  (['article', 'fucked', 'lion', 'future', 'fb'], 'Neg'),
#  (['rt',
#    'yellowgate',
#    'iphone',
#    'users',
#    'complain',
#    'yellow',
#    'tint',
#    'screen'],
#   'Neg'),
#  (['yellowgate', 'iphone', 'users', 'complain', 'yellow', 'tint', 'screen'],
#   'Neg'),
#  (['iphone',
#    'feature',
#    'missing',
#    'contacts',
#    'pictures',
#    'contacts',
#    'simple',
#    'major',
#    'updates',
#    'miss'],
#   'Neg'),
#  (['siri',
#    'dreams',
#    'electric',
#    'sleep',
#    'disappointed',
#    'snippy',
#    'answer',
#    'missed',
#    'opportunity'],
#   'Neg'),
#  (['surprises',
#    'throws',
#    'error',
#    'alert',
#    'authorizing',
#    'authorize',
#    'computer',
#    'button'],
#   'Neg'),
#  (['shh', 'evil', 'sith', 'lords', 'hear'], 'Neg'),
#  (['fuck', 'die', 'fucking', 'blaze', 'inferno'], 'Neg'),
#  (['oh',
#    'steve',
#    'obviously',
#    'iphoto',
#    'perfect',
#    'opposite',
#    'insanely',
#    'fixed',
#    'please'],
#   'Neg'),
#  (['omg', 'fuck', 'delete', 'music', 'dicks'], 'Neg'),
#  (['itunes', 'store', 'authorise', 'sign', 'itunes', 'grr'], 'Neg'),
#  (['seriously',
#    'absolutely',
#    'offing',
#    'clue',
#    'means',
#    'authorization',
#    'nor'],
#   'Neg'),
#  (['boy',
#    'harder',
#    'purchased',
#    'music',
#    'cloud',
#    'macbook',
#    'pro',
#    'authorize',
#    'computer'],
#   'Neg'),
#  (['shit',
#    'shit',
#    'shit',
#    'ios5',
#    'update',
#    'ate',
#    'apps',
#    'data',
#    'media',
#    'time',
#    'rebuild'],
#   'Neg'),
#  (['tell', 'iphone', 'la', 'fucking'], 'Neg'),
#  (['love',
#    'downloads',
#    'hours',
#    'ripstevejobs',
#    'thenonsensepersists',
#    'neednewipadguide',
#    'fatfuckingchance'],
#   'Neg'),
#  (['dear',
#    'air',
#    'notbook',
#    'update',
#    'killed',
#    'wifi',
#    'bug',
#    'destroying',
#    'productivity'],
#   'Neg'),
#  (['am', 'profitering', 'lack', 'customer', 'service', 'fucking'], 'Neg'),
#  (['send', 'phone', 'frustrated'], 'Neg'),
#  (['thank', 'ruining', 'ios5', 'phone', 'utterly', 'useless', 'pile', 'shit'],
#   'Neg'),
#  (['option', 'replacement', 'iphone', 'duff'], 'Neg'),
#  (['apparently', 'mb', 'cap', 'sms', 'update', 'storage', 'tells', 'inbox'],
#   'Neg'),
#  (['week', 'paid', 'itunes', 'match', 'eta', 'fix'], 'Neg'),
#  (['removing', 'shit'], 'Neg'),
#  (['iphone', 'giving', 'hella', 'hard', 'time', 'ios5', 'update'], 'Neg'),
#  (['sucks', 'hello', 'rt', 'note', 'droid', 'battery', 'removable'], 'Neg'),
#  (['send',
#    'iphone',
#    'preordered',
#    'launching',
#    'cans',
#    'send',
#    'jackasses',
#    'shoot',
#    'blend',
#    'em'],
#   'Neg'),
#  (['gotta',
#    'itouch',
#    'iphone',
#    'shuffle',
#    'etc',
#    'sound',
#    'quality',
#    'awful',
#    'painfully',
#    'crap',
#    'downgrade',
#    'sound',
#    'quality',
#    'wise'],
#   'Neg'),
#  (['upgrade',
#    'slows',
#    'phone',
#    'stuck',
#    'half',
#    'time',
#    'uch',
#    'thankfully',
#    'damage',
#    'sucks'],
#   'Neg'),
#  (['thorough',
#    'job',
#    'step',
#    'steps',
#    'upgrade',
#    'move',
#    'icloud',
#    'cost',
#    'mightily'],
#   'Neg'),
#  (['hey',
#    'ios5',
#    'iphone',
#    'include',
#    'songs',
#    'compilation',
#    'albums',
#    'name',
#    'whaddupwitdat'],
#   'Neg'),
#  (['send', 'rcve', 'txts', 'apt', 'waited'], 'Neg'),
#  (['total',
#    'chaos',
#    'store',
#    'regent',
#    'street',
#    'ethiopian',
#    'feeding',
#    'station',
#    'believe',
#    'co',
#    'makes',
#    'cool',
#    'shit'],
#   'Neg'),
#  (['purchase', 'wait', 'hate', 'bad', 'custserv'], 'Neg'),
#  (['buy',
#    'kudos',
#    'chris',
#    'alamo',
#    'ranch',
#    'issues',
#    'resolve',
#    'day',
#    'hero'],
#   'Neg'),
#  (['ppl', 'stand', 'line', 'hrs', 'model', 'suckers'], 'Neg'),
#  (['kill', 'braille', 'type', 'bump', 'earbuds', 'bud', 'dark'], 'Neg'),
#  (['wow', 'crushed', 'dreams'], 'Neg'),
#  (['rt', 'oh', 'fuck', 'iphone', 'schedule', 'summer', 'launch', 'via'],
#   'Neg'),
#  (['oh', 'fuck', 'iphone', 'schedule', 'summer', 'launch', 'via'], 'Neg'),
#  (['wait',
#    'thursday',
#    'available',
#    'appointment',
#    'genius',
#    'tell',
#    'shit',
#    'luck'],
#   'Neg'),
#  (['ios', 'allow', 'push', 'notifications', 'newstand', 'siri', 'yapping'],
#   'Neg'),
#  (['ipad', 'ios5', 'messages', 'icon', 'included'], 'Neg'),
#  (['sorry'], 'Neg'),
#  (['requires', 'reservation', 'apple', 'iphone'], 'Neg'),
#  (['iphone', 'battery', 'crappy', 'fail'], 'Neg'),
#  (['keyboard', 'type'], 'Neg'),
#  (['icloud', 'sync', 'stickies', 'progressed', 'apple'], 'Neg'),
#  (['save',
#    'version',
#    'function',
#    'pages',
#    'absolutely',
#    'awful',
#    'interrupting',
#    'piece',
#    'crap',
#    'world'],
#   'Neg'),
#  (['hate', 'computer', 'thats', 'dollars', 'drain'], 'Neg'),
#  (['iphone', 'charging'], 'Neg'),
#  (['ios5', 'gm', 'ipad1', 'slow', 'wash', 'solve', 'ipad2'], 'Neg'),
#  (['wish',
#    'pick',
#    'month',
#    'day',
#    'setting',
#    'calendar',
#    'item',
#    'iphone',
#    'ios',
#    'fixed'],
#   'Neg'),
#  (['itunes', 'worst', 'program', 'phone', 'awful', 'software'], 'Neg'),
#  (['voice', 'recognition', 'tech', 'support', 'line', 'little'], 'Neg'),
#  (['repair', 'ipad', 'apple', 'lost', 'android'], 'Neg'),
#  (['proper',
#    'consolidation',
#    'proper',
#    'syncing',
#    'stop',
#    'losing',
#    'purchased',
#    'items',
#    'checkboxes'],
#   'Neg'),
#  (['desktop', 'app', 'wack'], 'Neg'),
#  (['reservation', 'wait', 'line', 'oh', 'apple', 'store'], 'Neg'),
#  (['frustrated',
#    'bought',
#    'macbook',
#    'pro',
#    'doesnt',
#    'ship',
#    'expensivepaperweight'],
#   'Neg'),
#  (['dear',
#    'awesome',
#    'featured',
#    'enabled',
#    'data',
#    'plan',
#    'handle',
#    'mb',
#    'data'],
#   'Neg'),
#  (['dontbemadatmebecause', 'android'], 'Neg'),
#  (['ios',
#    'preventing',
#    'audio',
#    'apps',
#    'audio',
#    'functions',
#    'operating',
#    'properly',
#    'losing',
#    'sound'],
#   'Neg'),
#  (['apple',
#    'hater',
#    'mouse',
#    'buttery',
#    'finish',
#    'fast',
#    'am',
#    'happy',
#    'macworld'],
#   'Neg'),
#  (['hey', 'stop', 'sending', 'signal', 'iphone4', 'dying', 'rapidly'], 'Neg'),
#  (['bad',
#    'camera',
#    'compact',
#    'flash',
#    'cards',
#    'sd',
#    'sd',
#    'goes',
#    'computer',
#    'damn'],
#   'Neg'),
#  (['wtf',
#    'pages',
#    'terms',
#    'conditions',
#    'update',
#    'ur',
#    'apps',
#    'itunes',
#    'store',
#    'read',
#    'em'],
#   'Neg'),
#  (['fuck'], 'Neg'),
#  (['oh', 'prolly', 'ganna', 'late', 'bc', 'screwed', 'phone', 'alarm'], 'Neg'),
#  (['fuck',
#    'dose',
#    'phone',
#    'decide',
#    'ganna',
#    'freeze',
#    'time',
#    'try',
#    'update',
#    'fucking',
#    'sick'],
#   'Neg'),
#  (['text', 'wait', 'wont', 'cuz', 'fucks', 'time', 'fuckingpissed'], 'Neg'),
#  (['imessage', 'time', 'message', 'sent', 'annoying'], 'Neg'),
#  (['da', 'fuck', 'shit'], 'Neg'),
#  (['rt',
#    'wit',
#    'officially',
#    'boycotting',
#    'calling',
#    'curse',
#    'using',
#    'wasting'],
#   'Neg'),
#  (['damn', 'whatchu', 'phone'], 'Neg'),
#  (['samsung',
#    'seeks',
#    'iphone',
#    'ban',
#    'japan',
#    'australiapatent',
#    'war',
#    'intensifies',
#    'injunction',
#    'sought'],
#   'Neg'),
#  (['time',
#    'ios',
#    'software',
#    'update',
#    'ipad',
#    'goes',
#    'dead',
#    'totally',
#    'restore',
#    'fail'],
#   'Neg'),
#  (['pain', 'ass', 'music', 'photos', 'undo', 'garbage'], 'Neg'),
#  (['reservation',
#    'system',
#    'products',
#    'avail',
#    'iphone',
#    'site',
#    'browsers',
#    'pm'],
#   'Neg'),
#  (['rt', 'hear', 'trouble', 'brightness', 'andshuttingdownru'], 'Neg'),
#  (['hear',
#    'trouble',
#    'brightness',
#    'andshuttingdownrunningprograms',
#    'nohelp'],
#   'Neg'),
#  (['remember', 'evil', 'icloud', 'entering', 'dropbox', 'market'], 'Neg'),
#  (['issue', 'rt', 'charge', 'day', 'pissed'], 'Neg'),
#  (['charge', 'day', 'pissed'], 'Neg'),
#  (['rt', 'tell', 'time', 'muh', 'fuh'], 'Neg'),
#  (['wit', 'officially', 'boycotting', 'calling', 'curse', 'using', 'wasting'],
#   'Neg'),
#  (['youre', 'reservation', 'page', 'iphone'], 'Neg'),
#  (['itunes',
#    'worst',
#    'product',
#    'worse',
#    'newton',
#    'hockey',
#    'puck',
#    'mouse',
#    'utterly',
#    'painful'],
#   'Neg'),
#  (['der',
#    'icloud',
#    'hate',
#    'hope',
#    'die',
#    'worst',
#    'fucking',
#    'invention',
#    'world',
#    'fuck',
#    'youu',
#    'icloud'],
#   'Neg'),
#  (['update',
#    'ios',
#    'lose',
#    'phone',
#    'wont',
#    'sign',
#    'itunes',
#    'account',
#    'thanks'],
#   'Neg'),
#  (['suddenly', 'lost', 'address', 'book', 'iphone', 'using', 'id', 'fucked'],
#   'Neg'),
#  (['oh', 'iphone', 'overcapacity'], 'Neg'),
#  (['issues',
#    'updating',
#    'itunes',
#    'windows',
#    'pc',
#    'compatible',
#    'sent',
#    'time',
#    'talking',
#    'care',
#    'using'],
#   'Neg'),
#  (['guys', 'gay'], 'Neg'),
#  (['restored',
#    'iphone',
#    'texts',
#    'dear',
#    'love',
#    'restrictions',
#    'sms',
#    'texts',
#    'ios5',
#    'ios5atemydingo'],
#   'Neg'),
#  (['none', 'apps', 'ios'], 'Neg'),
#  (['seemingly',
#    'endless',
#    'loop',
#    'calls',
#    'investigate',
#    'missing',
#    'iphone4s',
#    'crankywithnophone'],
#   'Neg'),
#  (['hope'], 'Neg'),
#  (['phone', 'pretty', 'annoyed'], 'Neg'),
#  (['busy', 'phone', 'buy', 'stylus', 'wait', 'forever', 'outside'], 'Neg'),
#  (['please', 'deliver', 'i4s', 'driving', 'nuts', 'iphone'], 'Neg'),
#  (['word',
#    'iphone4s',
#    'preorder',
#    'buy',
#    'blames',
#    'sprint',
#    'sprint',
#    'blames',
#    'honest',
#    'answer',
#    'help'],
#   'Neg'),
#  (['hey', 'sms', 'message', 'complete', 'shit', 'yes', 'annoyed'], 'Neg'),
#  (['poor', 'customer', 'service', 'happened', 'apple', 'store'], 'Neg'),
#  (['service',
#    'experience',
#    'fucking',
#    'slipping',
#    'cute',
#    'eyelash',
#    'batting',
#    'apple'],
#   'Neg'),
#  (['ma',
#    'ipas',
#    'hours',
#    'jailbroke',
#    'shagged',
#    'itunes',
#    'letme',
#    'restore'],
#   'Neg'),
#  (['happened', 'snatched', 'siri', 'douchebags'], 'Neg'),
#  (['thinking',
#    'siri',
#    'totally',
#    'dependent',
#    'network',
#    'connection',
#    'siri',
#    'utter',
#    'frustration'],
#   'Neg'),
#  (['wow',
#    'genius',
#    'bar',
#    'reservation',
#    'line',
#    'ridic',
#    'am',
#    'amused',
#    'ugh'],
#   'Neg'),
#  ([], 'Neg'),
#  (['battery', 'life', 'suck', 'ios'], 'Neg'),
#  (['apple',
#    'update',
#    'render',
#    'machine',
#    'incapable',
#    'hdv',
#    'video',
#    'thanks',
#    'zero',
#    'useful',
#    'productivity'],
#   'Neg'),
#  (['committed',
#    'cloud',
#    'storage',
#    'idisk',
#    'raining',
#    'soon',
#    'idisk',
#    'plans',
#    'service',
#    'storage'],
#   'Neg'),
#  (['hey',
#    'share',
#    'reminder',
#    'list',
#    'login',
#    'icloud',
#    'webpage',
#    'modify',
#    'sharing',
#    'phone'],
#   'Neg'),
#  (['apparently',
#    'fuzzball',
#    'crashes',
#    'ios5',
#    'congratulations',
#    'incompatible',
#    'upgrade'],
#   'Neg'),
#  (['lion',
#    'please',
#    'integrate',
#    'vertical',
#    'spaces',
#    'mission',
#    'control',
#    'horizontal',
#    'business',
#    'nauseous'],
#   'Neg'),
#  (['plz',
#    'explain',
#    'whhyy',
#    'distributing',
#    'phones',
#    'day',
#    'sprint',
#    'stores'],
#   'Neg'),
#  (['gah',
#    'ios',
#    'text',
#    'messages',
#    'painfully',
#    'slow',
#    'top',
#    'restore',
#    'attempts',
#    'succeed',
#    'adopterness'],
#   'Neg'),
#  (['dear',
#    'pdfs',
#    'epub',
#    'files',
#    'disappear',
#    'ibooks',
#    'iphone',
#    'post',
#    'ios5',
#    'upgrade',
#    'hurts',
#    'needsomethingtoread'],
#   'Neg'),
#  (['lies',
#    'battery',
#    'iphone4s',
#    'definitely',
#    'check',
#    'times',
#    'app',
#    'usage',
#    'ios'],
#   'Neg'),
#  (['huge', 'podcast', 'fan', 'feel', 'dropped', 'ball', 'via'], 'Neg'),
#  (['voice', 'star', 'wars', 'voices'], 'Neg'),
#  (['hate',
#    'dealing',
#    'brain',
#    'dead',
#    'people',
#    'store',
#    'products',
#    'customer',
#    'service',
#    'sucks',
#    'nz'],
#   'Neg'),
#  (['hate',
#    'dealing',
#    'brain',
#    'dead',
#    'people',
#    'store',
#    'products',
#    'customer',
#    'service',
#    'sucks'],
#   'Neg'),
#  (['photo',
#    'albums',
#    'photos',
#    'app',
#    'ios',
#    'password',
#    'protect',
#    'um',
#    'fix',
#    'quickly'],
#   'Neg'),
#  (['else', 'seeing', 'missing', 'signal', 'bars', 'iphone', 'upgrade', 'ios5'],
#   'Neg'),
#  (['rt', 'lies', 'battery', 'iphone4s', 'definitely'], 'Neg'),
#  (['customers',
#    'dont',
#    'send',
#    'updates',
#    'noreply',
#    'return',
#    'address',
#    'invented',
#    'anyway',
#    'useless'],
#   'Neg'),
#  (['time',
#    'try',
#    'voice',
#    'control',
#    'ipod',
#    'touch',
#    'send',
#    'imessage',
#    'starts',
#    'playing',
#    'pink',
#    'flawless'],
#   'Neg'),
#  (['doing', 'hold', 'hurry', 'fuck', 'nopatience'], 'Neg'),
#  (['ok',
#    'hindi',
#    'keyboard',
#    'ios5',
#    'cheer',
#    'support',
#    'missing',
#    'indian',
#    'fail'],
#   'Neg'),
#  (['rt',
#    'iphone',
#    'apps',
#    'spontaneously',
#    'loose',
#    'data',
#    'fault',
#    'ios5downgrade'],
#   'Neg'),
#  (['figures', 'thx'], 'Neg'),
#  (['waiting', 'items', 'copy', 'itunes', 'copy', 'goes', 'hell'], 'Neg'),
#  (['unhappy', 'quality', 'buy'], 'Neg'),
#  (['lies', 'battery', 'iphone4s', 'definitely'], 'Neg'),
#  (['dear', 'gotta', 'change', 'handled', 'blue'], 'Neg'),
#  (['hold', 'customer', 'service', 'minutes', 'wow', 'timewarnercable'], 'Neg'),
#  (['else',
#    'stuck',
#    'duped',
#    'sucking',
#    'hell',
#    'icloud',
#    'osx',
#    'lion',
#    'disappointment'],
#   'Neg'),
#  (['inventor', 'computer', 'mouse', 'complete', 'piece', 'fucking'], 'Neg'),
#  (['killing',
#    'excited',
#    'ios5',
#    'tragic',
#    'battery',
#    'drain',
#    'genius',
#    'bar',
#    'replace',
#    'battery'],
#   'Neg'),
#  (['impressions',
#    'disappointed',
#    'upgrade',
#    'restore',
#    'lot',
#    'apps',
#    'folders',
#    'missing',
#    'time',
#    'in2',
#    'orging',
#    'fail'],
#   'Neg'),
#  (['question', 'remember'], 'Neg'),
#  (['multiple',
#    'times',
#    'siri',
#    'trouble',
#    'connecting',
#    'network',
#    'siri',
#    'servers'],
#   'Neg'),
#  (['imessage'], 'Neg'),
#  (['rt',
#    'resolve',
#    'siri',
#    'network',
#    'issues',
#    'rename',
#    'product',
#    'sorri',
#    'else',
#    'havin'],
#   'Neg'),
#  (['dear', 'gotta', 'change', 'handled', 'blue'], 'Neg'),
#  (['ugh', 'wtf', 'bottlenecks'], 'Neg'),
#  (['rt', 'please', 'fix', 'connect'], 'Neg'),
#  (['please', 'fix', 'connect'], 'Neg'),
#  (['resolve',
#    'siri',
#    'network',
#    'issues',
#    'rename',
#    'product',
#    'sorri',
#    'else',
#    'issues'],
#   'Neg'),
#  (['chance',
#    'release',
#    'headphones',
#    'dont',
#    'blast',
#    'music',
#    'outside',
#    'ears',
#    'iphone',
#    'ipod',
#    'obnoxious'],
#   'Neg'),
#  (['siri', 'due', 'network', 'seriously', 'fix', 'iphone4s', 'fail'], 'Neg'),
#  (['cloudy', 'tech', 'techy'], 'Neg'),
#  (['connect', 'process', 'commands', 'failing'], 'Neg'),
#  (['happen', 'release', 'iphone', 'crappy', 'design'], 'Neg'),
#  (['rt', 'looks', 'appropriately', 'project', 'resources', 'siri', 'reliable'],
#   'Neg'),
#  (['looks', 'appropriately', 'project', 'resources', 'siri', 'reliable'],
#   'Neg'),
#  (['spoke',
#    'rep',
#    'phone',
#    'hear',
#    'tv',
#    'blaring',
#    'bg',
#    'actually',
#    'help',
#    'direct',
#    'web'],
#   'Neg'),
#  (['wrong', 'siri'], 'Neg'),
#  (['siri'], 'Neg'),
#  (['suspecting',
#    'timed',
#    'iphone',
#    'perfectly',
#    'iphone',
#    'release',
#    'battery',
#    'seriously',
#    'ailing'],
#   'Neg'),
#  (['hold', 'half', 'hour', 'phone', 'ringing', 'picking', 'stink'], 'Neg'),
#  (['ok', 'software', 'update', 'iphone', 'taking', 'waay'], 'Neg'),
#  (['inform',
#    'customers',
#    'properly',
#    'migrating',
#    'icloud',
#    'complaints',
#    'lead',
#    'image',
#    'damage'],
#   'Neg'),
#  (['ios', 'rape', 'battery', 'life', 'am', 'using', 'phone', 'lot', 'getting'],
#   'Neg'),
#  (['hopefully', 'bug', 'fixing', 'apple', 'itjustworks'], 'Neg'),
#  (['realise', 'pissing', 'customer', 'base', 'looking', 'petty'], 'Neg'),
#  (['apps', 'am', 'updating', 'original', 'folder', 'location', 'painful'],
#   'Neg'),
#  (['domain',
#    'fail',
#    'hrs',
#    'late',
#    'walk',
#    'ppl',
#    'store',
#    'empty',
#    'skin',
#    'screen',
#    'represent',
#    'customer',
#    'service',
#    'fail'],
#   'Neg'),
#  (['chipsets',
#    'tear',
#    'battery',
#    'life',
#    'coworker',
#    'htc',
#    'thunderbolt',
#    'hours',
#    'life'],
#   'Neg'),
#  (['wish',
#    'apple',
#    'updater',
#    'stop',
#    'trying',
#    'ram',
#    'itunes',
#    'throat',
#    'own',
#    'pissing',
#    'iphone'],
#   'Neg'),
#  (['iphone', 'run', 'slower', 'ios', 'update'], 'Neg'),
#  (['searching', 'voice', 'nexus'], 'Neg'),
#  (['update',
#    'server',
#    'timing',
#    'week',
#    'force',
#    'restore',
#    'ios5',
#    'software',
#    'lost',
#    'stuff'],
#   'Neg'),
#  (['appleupdates2',
#    'success',
#    'iphone',
#    'ipad',
#    'phone',
#    'apple',
#    'mins',
#    'ipad',
#    'wasting',
#    'time'],
#   'Neg'),
#  (['thanks',
#    'minute',
#    'wait',
#    'hold',
#    'half',
#    'hour',
#    'actually',
#    'talking',
#    'tech',
#    'decides',
#    'send',
#    'email',
#    'fix',
#    'phone'],
#   'Neg'),
#  (['am', 'upset', 'inconvenienced', 'iphone', 'update', 'failed', 'backup'],
#   'Neg'),
#  (['seriously',
#    'finance',
#    'damn',
#    'phone',
#    'greedy',
#    'jolly',
#    'ass',
#    'gear',
#    'white',
#    'plz'],
#   'Neg'),
#  (['schedule',
#    'busy',
#    'spend',
#    'unquality',
#    'time',
#    'recover',
#    'iphone',
#    'mo',
#    'mobile',
#    'mo',
#    'immobile',
#    'sync'],
#   'Neg'),
#  (['pondering', 'ios', 'update', 'sounds', 'difficulties', 'hold', 'fix'],
#   'Neg'),
#  (['issues', 'dst', 'alarms'], 'Neg'),
#  (['book',
#    'genius',
#    'bar',
#    'hours',
#    'served',
#    'disappointing',
#    'apple',
#    'store',
#    'sydney',
#    'thanksfornothing'],
#   'Neg'),
#  (['apparently',
#    'genius',
#    'training',
#    'extend',
#    'clocks',
#    'service',
#    'half',
#    'hour',
#    'late',
#    'appointment'],
#   'Neg'),
#  (['screw',
#    'ios',
#    'download',
#    'crap',
#    'tired',
#    'trying',
#    'figured',
#    'connection',
#    'timing'],
#   'Neg'),
#  (['wow', 'mail', 'ios', 'upgrade', 'issues', 'hope', 'steve', 'jobs'], 'Neg'),
#  (['guys',
#    'test',
#    'upgrades',
#    'hrs',
#    'guys',
#    'wasted',
#    'time',
#    'yesterday',
#    'thanks'],
#   'Neg'),
#  (['ipad', 'freezes', 'iphone', 'techietroubles'], 'Neg'),
#  (['ipad',
#    'perpetual',
#    'restore',
#    'loop',
#    'trying',
#    'upgrade',
#    'ios5',
#    'sux',
#    'steve'],
#   'Neg'),
#  (['genius',
#    'apptment',
#    'running',
#    'late',
#    'day',
#    'row',
#    'dodgy',
#    'ipod',
#    'mega',
#    'hire',
#    'staff'],
#   'Neg'),
#  (['figure', 'properly', 'syncronize', 'iphone', 'ios5'], 'Neg'),
#  (['ave', 'store', 'told', 'wait', 'hours', 'needless', 'hotel', 'relaxing'],
#   'Neg'),
#  (['overall',
#    'am',
#    'fan',
#    'iphone',
#    'siri',
#    'issues',
#    'connecting',
#    'network'],
#   'Neg'),
#  (['terrible',
#    'customer',
#    'service',
#    'los',
#    'gatos',
#    'pay',
#    'bad',
#    'home',
#    'button'],
#   'Neg'),
#  (['thank', 'sucking', 'believe', 'sell', 'online'], 'Neg'),
#  (['major', 'battery', 'drain', 'issue', 'updating', 'iphone', 'ios', 'else'],
#   'Neg'),
#  (['dear', 'please', 'send', 'mac', 'book', 'surely', 'repair'], 'Neg'),
#  (['thanks',
#    'ios5',
#    'loving',
#    'music',
#    'breaking',
#    'talking',
#    'mobile',
#    'phone',
#    'bring',
#    'functional',
#    'iosdonwgrade'],
#   'Neg'),
#  (['ios5', 'iphone2', 'causes', 'camera', 'apperature', 'dilation', 'freeze'],
#   'Neg'),
#  (['ios5',
#    'geolocation',
#    'suburbs',
#    'words',
#    'drops',
#    'map',
#    'pins',
#    'please',
#    'fix'],
#   'Neg'),
#  (['sorry', 'imessage', 'bbm', 'disappointed'], 'Neg'),
#  (['iphone', 'siri', 'shit'], 'Neg'),
#  (['clarence',
#    'thomas',
#    'designed',
#    'osx',
#    'lion',
#    'tossing',
#    'decades',
#    'workflow',
#    'standards',
#    'bring',
#    'save',
#    'autosavesucks'],
#   'Neg'),
#  (['officially', 'hate', 'fix', 'damn', 'itunes'], 'Neg'),
#  (['dear',
#    'staff',
#    'little',
#    'rock',
#    'store',
#    'answered',
#    'questions',
#    'hard',
#    'questions'],
#   'Neg'),
#  (['yeah',
#    'except',
#    'receipt',
#    'takes',
#    'minutes',
#    'figure',
#    'printed',
#    'fix'],
#   'Neg'),
#  (['rt', 'hey', 'wanna', 'fix', 'fucking', 'playlist', 'piece', 'shit'],
#   'Neg'),
#  (['ipad', 'fantasy', 'football', 'app', 'app', 'ios', 'apps', 'running'],
#   'Neg'),
#  (['suck', 'dick', 'gotta', 'restore', 'ipad', 'annoyed'], 'Neg'),
#  (['line', 'stupid'], 'Neg'),
#  (['io5', 'upgrade', 'total', 'fail'], 'Neg'),
#  (['dear',
#    'contacts',
#    'terrible',
#    'cleaned',
#    'duplicates',
#    'hours',
#    'magically',
#    'reappeared',
#    'fix'],
#   'Neg'),
#  (['app', 'incompatible'], 'Neg'),
#  (['pissed', 'whoever', 'designs', 'keyboards', 'home', 'key', 'cli', 'keys'],
#   'Neg'),
#  (['mine', 'gone', 'recovered', 'saved', 'b4', 'upgraded', 'soo'], 'Neg'),
#  (['hey', 'wanna', 'fix', 'fucking', 'playlist', 'piece', 'shit'], 'Neg'),
#  (['siri',
#    'hard',
#    'time',
#    'remembering',
#    'sister',
#    'contact',
#    'card',
#    'space',
#    'family',
#    'info',
#    'iphone4s'],
#   'Neg'),
#  (['ios5',
#    'getting',
#    'sloppy',
#    'check',
#    'qa',
#    'team',
#    'issues',
#    'apps',
#    'data',
#    'syncing'],
#   'Neg'),
#  (['rt',
#    'sms',
#    'message',
#    'issue',
#    'ios5',
#    'update',
#    'trying',
#    'restore',
#    'else',
#    'fail',
#    'restore'],
#   'Neg'),
#  (['glad',
#    'paid',
#    'care',
#    'protection',
#    'plan',
#    'hold',
#    'minutes',
#    'customer',
#    'service'],
#   'Neg'),
#  (['happy', 'upgrade', 'itouch4', 'itouch', 'laptop', 'help'], 'Neg'),
#  (['goodriddance', 'cancer'], 'Neg'),
#  (['look', 'ipad', 'messages', 'crashes', 'app', 'maybe', 'fault'], 'Neg'),
#  (['icloud',
#    'wireless',
#    'updates',
#    'ios5',
#    'forces',
#    'computer',
#    'charge',
#    'ipod',
#    'touch',
#    'worstupdateever'],
#   'Neg'),
#  (['worries', 'bud', 'saying', 'lot', 'network', 'issues', 'mac'], 'Neg'),
#  (['hate', 'sending', 'toledooh', 'pre'], 'Neg'),
#  (['equipment', 'broke', 'guess', 'asus', 'genius', 'bar'], 'Neg'),
#  (['iphone', 'os', 'duplicating', 'ical', 'events', 'fix', 'icloud'], 'Neg'),
#  (['dear', 'iphone', 'ios5', 'update', 'apps'], 'Neg'),
#  (['hey', 'steve', 'jobs', 'died', 'twitter', 'ipad', 'app'], 'Neg'),
#  (['happy', 'apple', 'suggested', 'software', 'update'], 'Neg'),
#  (['smashed', 'iphone', 'screen', 'gonna', 'phone', 'tired', 'fixing'], 'Neg'),
#  (['ios5', 'save', 'contacts', 'nam', 'becuz', 'apple'], 'Neg'),
#  (['hell',
#    'able',
#    'restore',
#    'calendar',
#    'events',
#    'terrible',
#    'bug',
#    'icloud',
#    'anothericloudfail'],
#   'Neg'),
#  (['hate', 'hide', 'newsstand', 'app', 'move', 'folder', 'serves', 'purpose'],
#   'Neg'),
#  (['life', 'easier'], 'Neg'),
#  (['location', 'reminders', 'updating', 'ios'], 'Neg'),
#  (['comparing',
#    'live',
#    'apps',
#    'icloud',
#    'icloud',
#    'leading',
#    'crowd',
#    'agree'],
#   'Neg'),
#  (['rt', 'fix', 'ios5', 'week', 'buying', 'droid', 'emptythreats'], 'Neg'),
#  (['computer',
#    'fixed',
#    'meant',
#    'fuck',
#    'genius',
#    'bar',
#    'complain',
#    'annoyed'],
#   'Neg'),
#  (['fix', 'ios5', 'week', 'buying', 'droid', 'emptythreats'], 'Neg'),
#  (['pls',
#    'launch',
#    'siri',
#    'iphone4',
#    'disappointed',
#    'spending',
#    'hours',
#    'upgrading',
#    'ios5'],
#   'Neg'),
#  (['suck',
#    'fucking',
#    'iphones',
#    'glad',
#    'cause',
#    'service',
#    'fucking',
#    'terrible'],
#   'Neg'),
#  (['time', 'unhappy', 'product', 'disappointed', 'internet', 'confused', 'am'],
#   'Neg'),
#  (['week', 'ios5', 'considering', 'jailbroken', 'features', 'plus', 'stable'],
#   'Neg'),
#  (['issues', 'siri', 'reaching', 'network', 'signal'], 'Neg'),
#  (['ios5',
#    'completely',
#    'failed',
#    'upgrading',
#    'phone',
#    'stuck',
#    'restore',
#    'loop',
#    'thanks',
#    'wasting',
#    'day',
#    'undo'],
#   'Neg'),
#  (['iphone4s', 'run', 'little', 'warm', 'sometimes'], 'Neg'),
#  (['wtf', 'add', 'newsstand', 'walled', 'garden', 'please', 'remind'], 'Neg'),
#  (['seeing',
#    'none',
#    'microsoft',
#    'office',
#    'programs',
#    'anymore',
#    'lion',
#    'upgrade'],
#   'Neg'),
#  (['dear', 'newsstand', 'icon', 'screen', 'notcool'], 'Neg'),
#  (['quality', 'photos', 'iphone', 'photograherseye'], 'Neg'),
#  (['ok', 'idk', 'wth', 'syncing', 'phone', 'album', 'art', 'wtf'], 'Neg'),
#  (['wish', 'siri', 'tweet', 'fix'], 'Neg'),
#  (['waiting', 'deliver', 'phone'], 'Neg'),
#  (['purchase',
#    'product',
#    'rest',
#    'life',
#    'am',
#    'glad',
#    'steve',
#    'jobs',
#    'fucking',
#    'dead',
#    'fucking',
#    'rot'],
#   'Neg'),
#  (['thanks',
#    'imac',
#    'brick',
#    'lion',
#    'purchase',
#    'installed',
#    'former',
#    'owner'],
#   'Neg'),
#  (['siri',
#    'baby',
#    'lisa',
#    'told',
#    'sorry',
#    'trouble',
#    'connecting',
#    'network',
#    'server',
#    'fail',
#    'ios5'],
#   'Neg'),
#  (['deleted', 'tiger', 'woods', 'game', 'impossible', 'retrieve', 'thanks'],
#   'Neg'),
#  (['damn', 'breaking', 'continued', 'ios', 'apps', 'damn', 'overbearing'],
#   'Neg'),
#  (['yo', 'update', 'disaster'], 'Neg'),
#  (['dear',
#    'am',
#    'suing',
#    'insurance',
#    'company',
#    'managed',
#    'top',
#    'shit',
#    'list',
#    'ineedthosepictures'],
#   'Neg'),
#  (['dear', 'icloud', 'save', 'bandwidth', 'delete', 'document', 'ipad'],
#   'Neg'),
#  (['rt',
#    'dear',
#    'thank',
#    'beautiful',
#    'ios',
#    'features',
#    'miss',
#    'ones',
#    'lk',
#    'calls'],
#   'Neg'),
#  (['worst', 'experience', 'upgrading', 'version', 'ios', 'ios5'], 'Neg'),
#  (['happened', 'rt', 'purchasing', 'item'], 'Neg'),
#  (['purchasing', 'item'], 'Neg'),
#  (['rt',
#    'wow',
#    'worst',
#    'customer',
#    'service',
#    'experience',
#    'arrogant',
#    'inept',
#    'bad',
#    'combo',
#    'biltmore',
#    'apple',
#    'store'],
#   'Neg'),
#  (['wow',
#    'worst',
#    'customer',
#    'service',
#    'experience',
#    'arrogant',
#    'inept',
#    'bad',
#    'combo',
#    'biltmore',
#    'apple',
#    'store'],
#   'Neg'),
#  (['hey',
#    'guys',
#    'wtf',
#    'happening',
#    'iphone4',
#    'ios5',
#    'suddenly',
#    'fade',
#    'black',
#    'begin',
#    'vibrate',
#    'continuously',
#    'reboot'],
#   'Neg'),
#  (['play', 'nice', 'hdmi', 'ipad', 'pretty', 'lame'], 'Neg'),
#  (['iphone',
#    'apps',
#    'spontaneously',
#    'loose',
#    'data',
#    'fault',
#    'ios5downgrade'],
#   'Neg'),
#  (['images', 'photo', 'roll', 'seriously', 'fuck'], 'Neg'),
#  (['iphone4', 'plus', 'ios5', 'equal', 'half', 'battery', 'life'], 'Neg'),
#  (['itunes', 'updating', 'wanna', 'update', 'iphone', 'itunes', 'update'],
#   'Neg'),
#  (['credit',
#    'unless',
#    'credit',
#    'card',
#    'told',
#    'redeemed',
#    'cards',
#    'sound',
#    'fair'],
#   'Neg'),
#  (['siri', 'time', 'service', 'improve', 'monday', 'returning', 'iphone'],
#   'Neg'),
#  (['rt',
#    'mobileme',
#    'issues',
#    'syncing',
#    'accessing',
#    'mail',
#    'premise',
#    'icloud'],
#   'Neg'),
#  (['installing',
#    'ios',
#    'iphone4',
#    'am',
#    'stuck',
#    'iphone',
#    'screen',
#    'clicking'],
#   'Neg'),
#  (['bummer',
#    'icloud',
#    'syncs',
#    'windows',
#    'outlook',
#    'ie',
#    'firefox',
#    'sadmac'],
#   'Neg'),
#  (['disappointing',
#    'visual',
#    'merchandising',
#    'simple',
#    'lacks',
#    'elegance',
#    'sequence',
#    'tell',
#    'siri'],
#   'Neg'),
#  (['terminal', 'hold', 'person', 'trouble', 'iphone'], 'Neg'),
#  (['thanks', 'apple', 'ios', 'losing'], 'Neg'),
#  (['apps'], 'Neg'),
#  (['ios5',
#    'nonstop',
#    'dropped',
#    'button',
#    'randomly',
#    'cant',
#    'hear',
#    'pull',
#    'phone',
#    'ear',
#    'mobile',
#    'screen'],
#   'Neg'),
#  (['rt', 'occur', 'apple', 'ppl', 'share', 'itunes', 'accounts', 'amongst'],
#   'Neg'),
#  (['epicfail'], 'Neg'),
#  (['minutes', 'iphone', 'ios5', 'lost', 'charge', 'store', 'folks', 'ideas'],
#   'Neg'),
#  (['cutting', 'cord', 'makes', 'podcasts', 'harder', 'wth', 'ios5'], 'Neg'),
#  (['hour',
#    'ios5',
#    'iphone',
#    'gone',
#    'battery',
#    'charge',
#    'store',
#    'folks',
#    'solution'],
#   'Neg'),
#  (['screwing',
#    'iphone',
#    'resellars',
#    'dont',
#    'promised',
#    'similar',
#    'ma',
#    'monopolistic',
#    'prctices'],
#   'Neg'),
#  (['forget', 'stop', 'closing', 'app', 'store', 'bloody', 'purchase'], 'Neg'),
#  (['cu'], 'Neg'),
#  (['store',
#    'stumped',
#    'catastrophically',
#    'bad',
#    'battery',
#    'life',
#    'upgrading',
#    'ios5'],
#   'Neg'),
#  (['hmm',
#    'lot',
#    'siri',
#    'features',
#    'canada',
#    'location',
#    'directions',
#    'seriously'],
#   'Neg'),
#  (['siri', 'connect', 'network', 'useful', 'voicecontrol'], 'Neg'),
#  (['siri', 'exclusive', 'iphone', 'sorude'], 'Neg'),
#  (['total', 'time', 'phone', 'hour', 'minutes', 'goes'], 'Neg'),
#  (['waited',
#    'line',
#    'fucking',
#    'genius',
#    'called',
#    'app',
#    'john',
#    'jean',
#    'stop',
#    'fucking',
#    'name',
#    'im',
#    'french',
#    'boy',
#    'pcam'],
#   'Neg'),
#  (['dear', 'day', 'release', 'version', 'itunes', 'freeze', 'day'], 'Neg'),
#  (['reported', 'theft', 'iphone', 'return', 'call', 'promised'], 'Neg'),
#  (['bode',
#    'charging',
#    'night',
#    'iphone',
#    'battery',
#    'charger',
#    'calls',
#    'light'],
#   'Neg'),
#  (['houston', 'ipad', 'restoring', 'hours', 'installing', 'ios5'], 'Neg'),
#  (['siri', 'little', 'night', 'shit'], 'Neg'),
#  (['teamed',
#    'instead',
#    'sync',
#    'system',
#    'focus',
#    'car',
#    'sweet',
#    'sync',
#    'epicfail'],
#   'Neg'),
#  (['rt', 'itunes', 'click', 'music', 'movies', 'tv', 'playlists'], 'Neg'),
#  (['damn'], 'Neg'),
#  (['watched',
#    'folks',
#    'jihad',
#    'adobe',
#    'flash',
#    'plse',
#    'consider',
#    'youtube',
#    'link',
#    'future',
#    'ur',
#    'site'],
#   'Neutral'),
#  (['rt',
#    'record',
#    'quarter',
#    'bunch',
#    'professional',
#    'guessers',
#    'disappointmen'],
#   'Neutral'),
#  (['hey', 'androids', 'releasing', 'brand', 'art', 'phones', 'whens', 'phone'],
#   'Neutral'),
#  (['record',
#    'quarter',
#    'bunch',
#    'professional',
#    'guessers',
#    'disappointment',
#    'wtf'],
#   'Neutral'),
#  (['fun', 'integrate', 'soon', 'named', 'notifications'], 'Neutral'),
#  (['read', 'war', 'latter', 'agree', 'lack', 'innovation', 'specs'],
#   'Neutral'),
#  (['rt',
#    'takeaway',
#    'earnings',
#    'call',
#    'apple',
#    'iphone',
#    'release',
#    'months',
#    'stay',
#    'competitive',
#    'cc'],
#   'Neutral'),
#  (['takeaway',
#    'earnings',
#    'call',
#    'apple',
#    'iphone',
#    'release',
#    'months',
#    'stay',
#    'competitive'],
#   'Neutral'),
#  (['reports',
#    'lower',
#    'earnings',
#    'headline',
#    'reports',
#    'record',
#    'q1',
#    'earnings'],
#   'Neutral'),
#  (['win',
#    'ipod',
#    'touch',
#    'hello',
#    'world',
#    'baby',
#    'memories',
#    'pampershelloapps'],
#   'Neutral'),
#  (['expanded', 'app', 'store', 'countries', 'december', 'quarter'], 'Neutral'),
#  (['rolling', 'iphone', 'countries', 'month'], 'Neutral'),
#  (['coincidence', 'named', 'virtual', 'assistant', 'tom', 'robot', 'daughter'],
#   'Neutral'),
#  (['bad', 'results', 'depends', 'apparently'], 'Neutral'),
#  (['times',
#    'increasing',
#    'revenue',
#    'recession',
#    'considered',
#    'disappointment'],
#   'Neutral'),
#  (['people', 'waiting', 'line', 'phones', 'people', 'pun'], 'Neutral'),
#  (['outta', 'pic', 'fun', 'friends', 'choose', 'music'], 'Neutral'),
#  (['rt', 'tech', 'war', 'profiles'], 'Neutral'),
#  (['gonna', 'stayed', 'logged', 'fb', 'twitter', 'troublemaker'], 'Neutral'),
#  (['iphone'], 'Neutral'),
#  (['struggling', 'hold', 'online', 'iphone', 'thanks'], 'Neutral'),
#  (['hey',
#    'pretty',
#    'products',
#    'amazing',
#    'blow',
#    'minds',
#    'time',
#    'launch',
#    'gizmo',
#    'hold',
#    'music',
#    'crap'],
#   'Neutral'),
#  (['tech', 'war', 'profiles'], 'Neutral'),
#  (['pic', 'steve', 'jobs', 'home', 'page', 'honor'], 'Neutral'),
#  (['shut', 'wednesday', 'memorial'], 'Neutral'),
#  (['company'], 'Neutral'),
#  ([], 'Neutral'),
#  (['waiting',
#    'rt',
#    'project',
#    'steve',
#    'jobs',
#    'cranial',
#    'insertion',
#    'implant'],
#   'Neutral'),
#  (['apple',
#    'users',
#    'official',
#    'kalifornia',
#    'cavi',
#    'app',
#    'apple',
#    'device',
#    'powered',
#    'download',
#    'free'],
#   'Neutral'),
#  (['official',
#    'kalifornia',
#    'cavi',
#    'mobil',
#    'app',
#    'available',
#    'app',
#    'store',
#    'powered',
#    'download',
#    'free'],
#   'Neutral'),
#  (['win',
#    'ipod',
#    'touch',
#    'hello',
#    'world',
#    'baby',
#    'memories',
#    'pampershelloapps'],
#   'Neutral'),
#  (['ripsteve', 'rt', 'steve', 'jobs', 'seven', 'rules', 'success'], 'Neutral'),
#  (['macbreak', 'weekly', 'via', 'airplay', 'hd'], 'Neutral'),
#  (['stay', 'stay', 'foolish', 'ownership', 'complain', 'resilience'],
#   'Neutral'),
#  (['dear', 'smell', 'lawsuit', 'coming', 'motoactv'], 'Neutral'),
#  (['rt',
#    'paid',
#    'wait',
#    'line',
#    'store',
#    'morning',
#    'putapriceonconvenience',
#    'iphone',
#    'htt'],
#   'Neutral'),
#  (['buying'], 'Neutral'),
#  (['wireless',
#    'remote',
#    'keynote',
#    'presentations',
#    'macbook',
#    'air',
#    'pith',
#    'navigate',
#    'iphone'],
#   'Neutral'),
#  (['rt',
#    'dear',
#    'please',
#    'invent',
#    'facetime',
#    'voicemails',
#    'sincerely',
#    'haendel',
#    'balzora',
#    'jr',
#    'apple'],
#   'Neutral'),
#  (['win',
#    'ipod',
#    'touch',
#    'hello',
#    'world',
#    'baby',
#    'memories',
#    'pampershelloapps'],
#   'Neutral'),
#  (['dear',
#    'please',
#    'invent',
#    'facetime',
#    'voicemails',
#    'sincerely',
#    'haendel',
#    'balzora',
#    'jr',
#    'apple'],
#   'Neutral'),
#  (['rt',
#    'hi',
#    'household',
#    'iphones',
#    'ipads',
#    'minis',
#    'apple',
#    'tv',
#    'airports',
#    'timecapsule',
#    'whats',
#    'usable',
#    'iphoto',
#    'shari'],
#   'Neutral'),
#  (['couldnt',
#    'help',
#    'explored',
#    'iphone4s',
#    'store',
#    'talked',
#    'siri',
#    'tried',
#    'speak',
#    'nexttime'],
#   'Neutral'),
#  (['people',
#    'miss',
#    'ipod',
#    'symbol',
#    'iphone',
#    'ipod',
#    'relate',
#    'ios5',
#    'nostalgia'],
#   'Neutral'),
#  (['iphone',
#    'att',
#    'contract',
#    'buy',
#    'factory',
#    'unlocked',
#    'iphone',
#    'contract'],
#   'Neutral'),
#  (['rt', 'rt', 'fan', 'eric', 'holder', 'spotted', 'genius', 'store'],
#   'Neutral'),
#  (['hi',
#    'household',
#    'iphones',
#    'ipads',
#    'minis',
#    'apple',
#    'tv',
#    'airports',
#    'timecapsule',
#    'whats',
#    'usable',
#    'iphoto',
#    'sharing',
#    'setup'],
#   'Neutral'),
#  (['rt',
#    'genius',
#    'bar',
#    'rt',
#    'fan',
#    'eric',
#    'holder',
#    'spotted',
#    'genius',
#    'store'],
#   'Neutral'),
#  (['motoactiv', 'methinks', 'maybe', 'prepping', 'lawsuits'], 'Neutral'),
#  (['check',
#    'video',
#    'moe',
#    'plays',
#    'live',
#    'ipads',
#    'video',
#    'dedicated',
#    'memory',
#    'stevejobs',
#    'brilliant'],
#   'Neutral'),
#  (['genius',
#    'bar',
#    'rt',
#    'fan',
#    'eric',
#    'holder',
#    'spotted',
#    'genius',
#    'store'],
#   'Neutral'),
#  (['evolution', 'ads', 'stevejobs', 'tech', 'art'], 'Neutral'),
#  (['siri'], 'Neutral'),
#  (['rt', 'fan', 'eric', 'holder', 'spotted', 'genius', 'store'], 'Neutral'),
#  (['rt', 'fan', 'eric', 'holder', 'spotted', 'genius', 'store'], 'Neutral'),
#  (['rt', 'fan', 'eric', 'holder', 'spotted', 'genius', 'store'], 'Neutral'),
#  (['fan', 'eric', 'holder', 'spotted', 'genius', 'store'], 'Neutral'),
#  (['rt', 'app', 'iphone', 'simple', 'easy'], 'Neutral'),
#  (['app', 'iphone', 'simple', 'easy'], 'Neutral'),
#  (['thanks',
#    'people',
#    'bus',
#    'talking',
#    'inanimate',
#    'objects',
#    'harder',
#    'tell',
#    'crazy',
#    'hip'],
#   'Neutral'),
#  (['noticed', 'added', 'tweet', 'icons', 'page', 'facebook', 'tweet'],
#   'Neutral'),
#  (['thx', 'publicly', 'coming', 'closet'], 'Neutral'),
#  (['win',
#    'ipod',
#    'touch',
#    'hello',
#    'world',
#    'baby',
#    'memories',
#    'pampershelloapps'],
#   'Neutral'),
#  (['release', 'generation', 'phones', 'contend', 'hmm'], 'Neutral'),
#  (['rt', 'ios', 'system', 'day', 'download'], 'Neutral'),
#  (['using', 'mobile', 'utility'], 'Neutral'),
#  (['balked', 'acquisition', 'apps', 'thank'], 'Neutral'),
#  (['cos', 'worth', 'battling', 'consumers', 'via'], 'Neutral'),
#  (['tomcruise', 'unique', 'name', 'daughter', 'pulls', 'rug', 'siri', 'app'],
#   'Neutral'),
#  (['wonder', 'person', 'holding', 'apple', 'buy'], 'Neutral'),
#  (['ios', 'iphone', 'ipad', 'release', 'ios5', 'ios', 'ipad', 'tablet'],
#   'Neutral'),
#  (['tech', 'battle', 'future', 'via'], 'Neutral'),
#  (['am', 'aye'], 'Neutral'),
#  (['community', 'stevejobs', 'community', 'icelebrates', 'steve', 'jobs'],
#   'Neutral'),
#  (['steve',
#    'jobs',
#    'unconventional',
#    'leadership',
#    'secret',
#    'acc',
#    'sm',
#    'hr',
#    'nehra'],
#   'Neutral'),
#  (['rt',
# ...
#    'management',
#    'innovation'],
#   'Neutral'),
#  (['ok'], 'Neutral'),
#  (['cat', 'accusing', 'tiger', 'roaring', 'samsung'], 'Neutral'),
#  (['partner', 'app', 'store'], 'Neutral'),
#  (['stuck',
#    'unveiled',
#    'icloud',
#    'placement',
#    'name',
#    'failed',
#    'effort',
#    'yields',
#    'success'],
#   'Neutral'),
#  (['left', 'week', 'iphone4s', 'apple'], 'Neutral'),
#  (['call', 'genius'], 'Neutral'),
#  (['stock', 'stevejobs', 'death', 'apple', 'applestock'], 'Neutral'),
#  (['steve',
#    'jobs',
#    'tribute',
#    'promoting',
#    'brand',
#    'cloud',
#    'front',
#    'page',
#    'start',
#    'explaining'],
#   'Neutral'),
#  (['magazine',
#    'own',
#    'supports',
#    'magazines',
#    'ipad',
#    'upgrade',
#    'adds',
#    'newsstand',
#    'app'],
#   'Neutral'),
#  (['busy', 'slappy', 'samsung'], 'Neutral'),
#  (['fregon',
#    'el',
#    'nuevo',
#    'facebook',
#    'para',
#    'haha',
#    'alomejor',
#    'ya',
#    'tiene',
#    'rato',
#    'pero',
#    'yo',
#    'lo',
#    'acabo',
#    'de',
#    'actualizar'],
#   'Neutral'),
#  (['rt', 'siri', 'trying', 'send', 'escort', 'legal'], 'Neutral'),
#  (['siri', 'trying', 'send', 'escort', 'legal'], 'Neutral'),
#  (['watching', 'igenius', 'based', 'minutes', 'gone', 'public'], 'Neutral'),
#  (['ok', 'lion', 'leopard', 'upgrading', 'weekend'], 'Neutral'),
#  (['maybe', 'set', 'ya', 'products', 'send', 'push', 'notifications'],
#   'Neutral'),
#  (['siri', 'google', 'android', 'functionality', 'justsaying'], 'Neutral'),
#  (['win',
#    'ipod',
#    'touch',
#    'hello',
#    'world',
#    'baby',
#    'memories',
#    'pampershelloapps'],
#   'Neutral'),
#  (['hmm', 'checked', 'identity'], 'Neutral'),
#  (['respect', 'apple', 'logo', 'revised', 'doubt', 'seen'], 'Neutral'),
#  (['win',
#    'ipod',
#    'touch',
#    'hello',
#    'world',
#    'baby',
#    'memories',
#    'pampershelloapps'],
#   'Neutral'),
#  (['buying', 'ipads', 'break', 'learn', 'cope', 'post', 'steve', 'apple'],
#   'Neutral'),
#  (['buy', 'iphone', 'store', 'defrauding'], 'Neutral'),
#  (['haha', 'sad'], 'Neutral'),
#  (['contract', 'deal', 'customers', 'time', 'teamiphone'], 'Neutral'),
#  (['vs', 'winning'], 'Neutral'),
#  (['steve', 'jobs', 'biopic', 'coming', 'soon', 'apple', 'stevejobs'],
#   'Neutral'),
#  (['yes',
#    'salute',
#    'steve',
#    'jobs',
#    'tweeting',
#    'watching',
#    'ipad',
#    'schaub',
#    'time',
#    'lead'],
#   'Neutral'),
#  (['wow',
#    'earlier',
#    'upstairs',
#    'huge',
#    'soho',
#    'store',
#    'sudden',
#    'sprung',
#    'attention'],
#   'Neutral'),
#  (['digital', 'worldwide', 'steve', 'jobs', 'day', 'california'], 'Neutral'),
#  (['watching', 'webcast', 'joseph', 'ipad', 'tv', 'love', 'technology'],
#   'Neutral'),
#  (['comparing', 'imagine', 'worse', 'sadreally'], 'Neutral'),
#  (['waiting', 'patiently', 'store'], 'Neutral'),
#  (['knowing'], 'Neutral'),
#  (['rt', 'principal', 'global', 'players', 'active', 'fbf11', 'publaunch'],
#   'Neutral'),
#  (['via'], 'Neutral'),
#  (['told', 'stupid', 'bitch', 'reply', 'insist', 'lol'], 'Neutral'),
#  (['check', 'notes', 'lion', 'icloud', 'ios', 'devices'], 'Neutral'),
#  (['siri',
#    'favorite',
#    'color',
#    'average',
#    'speed',
#    'unladen',
#    'swallow',
#    'monty',
#    'python',
#    'fan'],
#   'Neutral'),
#  (['principal', 'global', 'players', 'active', 'fbf11', 'publaunch'],
#   'Neutral'),
#  (['publicly', 'denounce', 'file', 'suit', 'buy', 'em', 'cheap', 'siri'],
#   'Neutral'),
#  (['lost', 'lot', 'paid', 'nothappy', 'oh', 'poop', 'happens'], 'Neutral'),
#  (['folks', 'glad', 'mactard'], 'Neutral'),
#  (['waiting',
#    'person',
#    'line',
#    'checking',
#    'time',
#    'genius',
#    'bar',
#    'appt',
#    'system',
#    'genius',
#    'fail'],
#   'Neutral'),
#  (['improvements',
#    'mac',
#    'os',
#    'lion',
#    'implementation',
#    'monitors',
#    'broken'],
#   'Neutral'),
#  (['apple', 'read', 'messages', 'twitter', 'apple'], 'Neutral'),
#  (['heard', 'hubby'], 'Neutral'),
#  (['rt', 'partnership', 'sms', 'ios', 'devices', 'imessage'], 'Neutral'),
#  (['california',
#    'governor',
#    'declares',
#    'stevejobsday',
#    'music',
#    'video',
#    'tribute'],
#   'Neutral'),
#  (['lmao', 'rt', 'siri', 'hoes', 'told', 'nearest', 'escorts', 'love'],
#   'Neutral'),
#  (['beef', 'cantwealljustgetalong'], 'Neutral'),
#  (['siri', 'hoes', 'told', 'nearest', 'escorts', 'love'], 'Neutral'),
#  (['switch', 'looking', 'bbwho'], 'Neutral'),
#  (['twitpeeps', 'user', 'liking', 'ios'], 'Neutral'),
#  (['rt', 'prasing', 'ios5everyone', 'subscribe', 'shamlesselfpromotion'],
#   'Neutral'),
#  (['prasing', 'ios5everyone', 'subscribe', 'shamlesselfpromotion'], 'Neutral'),
#  (['shit', 'hard', 'change', 'twitter', 'name'], 'Neutral'),
#  (['siri', 'iphone4'], 'Neutral'),
#  (['imessage', 'default', 'sms', 'wifi', 'limited', 'data'], 'Neutral'),
#  (['migrate',
#    'mbp',
#    'imac',
#    'using',
#    'ethernet',
#    'firewire',
#    'thanks',
#    'drew',
#    'saving'],
#   'Neutral'),
#  (['dear',
#    'yesterday',
#    'sucked',
#    'thanks',
#    'lp',
#    'apple',
#    'store',
#    'crash',
#    'burn',
#    'mich',
#    'ave',
#    'store'],
#   'Neutral'),
#  (['store',
#    'towson',
#    'waiting',
#    'genius',
#    'bar',
#    'huge',
#    'crowd',
#    'waiting',
#    'iphone'],
#   'Neutral'),
#  (['steve', 'jobs', 'day', 'pcworld'], 'Neutral'),
#  (['respond', 'fast', 'ios5'], 'Neutral'),
#  (['totally', 'agree', 'talking', 'yesterday', 'siri'], 'Neutral'),
#  (['factories', 'cost', 'asymco'], 'Neutral'),
#  (['hits', 'court'], 'Neutral'),
#  (['told', 'happened', 'concrete', 'evidence', 'logging', 'life'], 'Neutral'),
#  (['pick'], 'Neutral'),
#  (['iphone'], 'Neutral'),
#  (['loves', 'iphone', 'blogpost', 'finally', 'iphone', 'apps'], 'Neutral'),
#  (['explain', 'hell', 'imessage', 'differs', 'text', 'message', 'fb'],
#   'Neutral'),
#  (['explain', 'hell', 'imessage', 'differs', 'text', 'message'], 'Neutral'),
#  (['feel', 'free', 'accidently', 'ship', 'iphone', 'nobigdeal'], 'Neutral'),
#  (['siri', 'swallowed', 'relied', 'wtf', 'wank', 'phone'], 'Neutral'),
#  (['win',
#    'ipod',
#    'touch',
#    'hello',
#    'world',
#    'baby',
#    'memories',
#    'pampershelloapps'],
#   'Neutral'),
#  (['student', 'discount', 'macbook', 'air', 'canada', 'reps', 'laptop'],
#   'Neutral'),
#  (['provide', 'ability', 'password', 'protect', 'ipad', 'email'], 'Neutral'),
#  (['ios5',
#    'changed',
#    'ipad',
#    'charges',
#    'noticed',
#    'charge',
#    'laptop',
#    'iphone',
#    'charger'],
#   'Neutral'),
#  (['awesome', 'sold', 'ipads', 'easy', 'pay', 'yesplease'], 'Neutral'),
#  (['thanks', 'girlfriend', 'likes', 'siri'], 'Neutral'),
#  (['store',
#    'dude',
#    'hear',
#    'accent',
#    'ru',
#    'ct',
#    'ur',
#    'tell',
#    'dude',
#    'maybe'],
#   'Neutral'),
#  (['speechtrans',
#    'app',
#    'store',
#    'listed',
#    'speech',
#    'speech',
#    'translator',
#    'posts',
#    'twitter'],
#   'Neutral'),
#  (['chance',
#    'check',
#    'android',
#    'overhaul',
#    'ebooks',
#    'response',
#    'newsstand',
#    'baked',
#    'ios5'],
#   'Neutral'),
#  (['siri',
#    'support',
#    'canada',
#    'sucks',
#    'siri',
#    'loving',
#    'iphone',
#    'upgrade',
#    'iphone4s'],
#   'Neutral'),
#  (['awesome', 'documentary', 'apple', 'created', 'stevejobs', 'apple'],
#   'Neutral'),
#  (['apparently', 'tweetbarassment'], 'Neutral'),
#  (['video', 'brought', 'tear', 'eye', 'watch', 'opinion', 'stevejobs'],
#   'Neutral'),
#  (['reader', 'button', 'safari', 'perfect', 'fic', 'ios5', 'stevejobsday'],
#   'Neutral'),
#  (['macbook',
#    'pros',
#    'constrained',
#    'models',
#    'appear',
#    'apples',
#    'inventory',
#    'system'],
#   'Neutral'),
#  (['iphone', 'review'], 'Neutral'),
#  (['siri'], 'Neutral'),
#  (['lunched', 'iso'], 'Neutral'),
#  (['bouquet', 'jobs', 'store', 'nagoya'], 'Neutral'),
#  (['ios5',
#    'notification',
#    'center',
#    'improvement',
#    'missed',
#    'easy',
#    'trick',
#    'available',
#    'lock',
#    'screen'],
#   'Neutral'),
#  ([], 'Neutral'),
#  (['battle',
#    'voice',
#    'controlled',
#    'ai',
#    'platforms',
#    'mobile',
#    'os',
#    'ind',
#    'ie',
#    'antitrust',
#    'eu',
#    'vlingo'],
#   'Neutral'),
#  (['speechtrans',
#    'app',
#    'store',
#    'listed',
#    'speech',
#    'speech',
#    'translator',
#    'posts',
#    'twitter'],
#   'Neutral'),
#  (['win',
#    'ipod',
#    'touch',
#    'hello',
#    'world',
#    'baby',
#    'memories',
#    'pampershelloapps'],
#   'Neutral'),
#  (['hide',
#    'rt',
#    'dear',
#    'newsstand',
#    'advertise',
#    'magazines',
#    'remove',
#    'app'],
#   'Neutral'),
#  (['win',
#    'ipod',
#    'touch',
#    'hello',
#    'world',
#    'baby',
#    'memories',
#    'pampershelloapps'],
#   'Neutral'),
#  (['win',
#    'ipod',
#    'touch',
#    'hello',
#    'world',
#    'baby',
#    'memories',
#    'pampershelloapps'],
#   'Neutral'),
#  (['change', 'homepage', 'steve', 'jobs', 'looks', 'owl'], 'Neutral'),
#  (['integrate', 'siri'], 'Neutral'),
#  (['nope', 'mom', 'switch', 'upgrade', 'mine', 'til', 'march'], 'Neutral'),
#  (['ios5', 'nice', 'features', 'waiting', 'app'], 'Neutral'),
#  (['tribute',
#    'steve',
#    'consider',
#    'renaming',
#    'siri',
#    'steve',
#    'jobs',
#    'forever',
#    'remembered',
#    'legacy'],
#   'Neutral'),
#  (['wait', 'integrate', 'siri'], 'Neutral'),
#  (['account'], 'Neutral'),
#  (['hope', 'release', 'app', 'siri', 'users', 'apple', 'iphone', 'siri'],
#   'Neutral'),
#  (['strange', 'newsstand', 'app', 'paperboy', 'ios', 'iphone'], 'Neutral'),
#  (['curious',
#    'iphone',
#    'apple',
#    'iphone',
#    'price',
#    'features',
#    'healthit',
#    'ehr'],
#   'Neutral'),
#  (['lemme', 'ios5', 'mad', 'cool', 'lot', 'bug', 'fixes'], 'Neutral'),
#  (['instead', 'dropping', 'iphone', 'release'], 'Neutral'),
#  (['dear', 'imessage', 'client', 'desktop', 'please'], 'Neutral'),
#  (['siri', 'kinda', 'slow', 'tho', 'impressed', 'accent', 'commands', 'time'],
#   'Neutral'),
#  (['genius', 'songs', 'watch', 'throne', 'huh'], 'Neutral'),
#  (['win',
#    'ipod',
#    'touch',
#    'hello',
#    'world',
#    'baby',
#    'memories',
#    'pampershelloapps'],
#   'Neutral'),
#  (['speechtrans',
#    'app',
#    'store',
#    'listed',
#    'speech',
#    'speech',
#    'translator',
#    'posts',
#    'twitter'],
#   'Neutral'),
#  (['iphone'], 'Neutral'),
#  (['hq'], 'Neutral'),
#  (['trip', 'sf', 'silicon', 'valley', 'visit', 'hq', 'final', 'stops'],
#   'Neutral'),
#  (['iphone4s', 'space', 'via'], 'Neutral'),
#  (['rt',
#    'hey',
#    'iphone4s',
#    'iphone',
#    'steve',
#    'donate',
#    'portion',
#    'proceeds',
#    'towards',
#    'cancer',
#    'rese'],
#   'Neutral'),
#  (['win',
#    'ipod',
#    'touch',
#    'hello',
#    'world',
#    'baby',
#    'memories',
#    'pampershelloapps'],
#   'Neutral'),
#  (['wish',
#    'native',
#    'mac',
#    'version',
#    'video',
#    'editor',
#    'especially',
#    'hd',
#    'video',
#    'love'],
#   'Neutral'),
#  ([], 'Neutral'),
#  (['siri', 'avalible', 'devices', 'exclusive', 'iphone'], 'Neutral'),
#  (['line', 'store', 'hillsdale', 'mall'], 'Neutral'),
#  ([], 'Neutral'),
#  (['volume',
#    'control',
#    'fast',
#    'app',
#    'buttons',
#    'volume',
#    'buttons',
#    'brightness',
#    'wtf'],
#   'Neutral'),
#  (['proof',
#    'dad',
#    'loves',
#    'sis',
#    'rt',
#    'woke',
#    'dad',
#    'door',
#    'iphone',
#    'surprised'],
#   'Neutral'),
#  (['iphone', 'arrival', 'iphone4s'], 'Neutral'),
#  (['iphones', 'firstworldproblems'], 'Neutral'),
#  (['dear',
#    'user',
#    'please',
#    'add',
#    'options',
#    'stronger',
#    'vibrate',
#    'iphone4s',
#    'thank',
#    'hoh',
#    'deaf',
#    'ally'],
#   'Neutral'),
#  (['genius', 'bar', 'waiting', 'store'], 'Neutral'),
#  (['kidding',
#    'forget',
#    'stop',
#    'closing',
#    'app',
#    'store',
#    'bloody',
#    'purchase'],
#   'Neutral'),
#  (['giant', 'silver', 'door', 'store', 'maclife'], 'Neutral'),
#  (['url'], 'Neutral'),
#  (['looking',
#    'samsung',
#    'chaton',
#    'tonight',
#    'promising',
#    'integrated',
#    'key',
#    'apps'],
#   'Neutral'),
#  (['unlocking', 'store', 'rip', 'jobs'], 'Neutral'),
#  (['siri',
#    'cool',
#    'importantly',
#    'handy',
#    'funny',
#    'please',
#    'configure',
#    'canada',
#    'racism',
#    'eh'],
#   'Neutral'),
#  (['rt',
#    'yea',
#    'stores',
#    'days',
#    'week',
#    'rt',
#    'rt',
#    'ipad',
#    'iphone',
#    'christmas',
#    'gifts',
#    'self'],
#   'Neutral'),
#  (['ios5', 'include', 'landscape', 'mode', 'reminders'], 'Neutral'),
#  (['de',
#    'la',
#    'nada',
#    'mi',
#    'iphone4',
#    'se',
#    'fue',
#    'negro',
#    'empez',
#    'vibrar',
#    'hubo',
#    'que',
#    'resetearlo',
#    'que',
#    'onda',
#    'con',
#    'ios5',
#    'wtfh'],
#   'Neutral'),
#  (['line', 'northpark', 'dallas', 'mall'], 'Neutral'),
#  (['sounds', 'day', 'strategy', 'ours', 'yesterday', 'time', 'staff'],
#   'Neutral'),
#  (['slow',
#    'slow',
#    'slow',
#    'beware',
#    'signing',
#    'slowsprint',
#    'iphone',
#    'iphone4',
#    'iphone4s',
#    'siri',
#    'android',
#    'thebufferingnetwork'],
#   'Neutral'),
#  (['waiting', 'line', 'store', 'west', 'street'], 'Neutral'),
#  (['honor', 'steve', 'jobs', 'ripsteve'], 'Neutral'),
#  (['gonna', 'update', 'emoji', 'twitter', 'mac'], 'Neutral'),
#  (['rt',
#    'purdie',
#    'rogers',
#    'tribute',
#    'stevejobs',
#    'spray',
#    'painted',
#    'macintosh',
#    'plus'],
#   'Neutral'),
#  (['rt',
#    'purdie',
#    'rogers',
#    'tribute',
#    'stevejobs',
#    'spray',
#    'painted',
#    'macintosh',
#    'plus'],
#   'Neutral'),
#  (['ios', 'support', 'gen', 'ipods', 'discontinued', 'ios', 'update'],
#   'Neutral'),
#  (['look', 'ebay', 'iphone', 'bids', 'delivered'], 'Neutral'),
#  (['shit', 'siri', 'designers', 'people', 'digital', 'assistant'], 'Neutral'),
#  (['buddy', 'surprised', 'option', 'brings', 'pics', 'delete'], 'Neutral'),
#  (['speechtrans',
#    'app',
#    'store',
#    'listed',
#    'speech',
#    'speech',
#    'translator',
#    'posts',
#    'twitter'],
#   'Neutral'),
#  (['changed', 'look', 'toggle', 'wonder', 'hip', 'web', 'apps', 'follow'],
#   'Neutral'),
#  (['earth', 'imessage', 'anyway', 'world', 'imessage', 'giving', 'phone'],
#   'Neutral'),
#  (['rt',
#    'wall',
#    'wall',
#    'people',
#    'security',
#    'huge',
#    'line',
#    'outside',
#    'store'],
#   'Neutral'),
#  (['line', 'store', 'glendale', 'iphone'], 'Neutral'),
#  (['follow', 'follow'], 'Neutral'),
#  (['salesperson',
#    'soho',
#    'store',
#    'matter',
#    'people',
#    'lined',
#    'front',
#    'gonna',
#    'iphone4s'],
#   'Neutral'),
#  (['looking', 'outside', 'sticky', 'notes', 'steve', 'jobs'], 'Neutral'),
#  (['rest', 'battle', 'court'], 'Neutral'),
#  (['iphone',
#    'update',
#    'seriously',
#    'delete',
#    'stuff',
#    'dont',
#    'gamecenter',
#    'steve',
#    'wont',
#    'mind'],
#   'Neutral'),
#  (['mine', 'past', 'warranty', 'applecare', 'ios5'], 'Neutral'),
#  (['usb', 'female', 'connector', 'cars', 'dope'], 'Neutral'),
#  (['flash', 'ipad', 'please', 'please', 'please', 'change', 'mind', 'thank'],
#   'Neutral'),
#  (['time', 'app', 'called', 'isuck', 'apps', 'killing', 'battery', 'life'],
#   'Neutral'),
#  (['min', 'line', 'store', 'pump'], 'Neutral'),
#  (['lol', 'support', 'playing', 'mary', 'blige', 'wait', 'time'], 'Neutral'),
#  (['rt', 'sprint', 'verizon', 'stores'], 'Neutral'),
#  (['icloud', 'weather', 'stocks', 'pre', 'ios5', 'hopeful', 'help'],
#   'Neutral'),
#  (['thinking',
#    'android',
#    'imessage',
#    'service',
#    'interconnect',
#    'cared',
#    'users'],
#   'Neutral'),
#  (['domain', 'location', 'umbrellas', 'nice', 'staffed', 'properly'],
#   'Neutral'),
#  (['bored', 'intriguing', 'app', 'ipad', 'suggestions', 'yyc'], 'Neutral'),
#  (['fixed', 'bug', 'thursday', 'update', 'issue', 'spent', 'fri', 'ios5'],
#   'Neutral'),
#  (['mbp', 'run', 'lion', 'sync'], 'Neutral'),
#  (['people',
#    'standing',
#    'middle',
#    'saying',
#    'siri',
#    'told',
#    'noreallyihearvoices'],
#   'Neutral'),
#  (['siri',
#    'talking',
#    'iphones',
#    'people',
#    'truly',
#    'crazy',
#    'iphone4s',
#    'siri',
#    'apple'],
#   'Neutral'),
#  (['able', 'afford', 'mansion', 'day'], 'Neutral'),
#  (['ios', 'desktop', 'app'], 'Neutral'),
#  (['wished', 'hold', 'music', 'played', 'pictures'], 'Neutral'),
#  (['upgrade', 'helpful', 'maddening'], 'Neutral'),
#  (['hold',
#    'mins',
#    'music',
#    'selection',
#    'music',
#    'white',
#    'stripes',
#    'ray',
#    'lamontagne'],
#   'Neutral'),
#  (['win',
#    'ipod',
#    'touch',
#    'hello',
#    'world',
#    'baby',
#    'memories',
#    'pampershelloapps'],
#   'Neutral'),
#  (['poor', 'substitute', 'yo', 'gimmie'], 'Neutral'),
#  (['scrapple'], 'Neutral'),
#  (['oh', 'lot', 'dough', 'spend', 'otherwise'], 'Neutral'),
#  (['entrepreneurs', 'died', 'steve', 'jobs', 'passed', 'hearts', 'family'],
#   'Neutral'),
#  (['tomorrow', 'hectic', 'cause', 'moms', 'store'], 'Neutral')]

# %%
#start extract_features
def extract_features(tweet):
    tweet_words = set(tweet)
    features = {}
    for word in featureList:
        features['contains(%s)' % word] = (word in tweet_words)
    return features

# %%
### Remove featureList duplicates
featureList = list(set(featureList))

# %%
import nltk
training_set = nltk.classify.util.apply_features(extract_features, tweets)
# Train the classifier Naive Bayes Classifier
NBClassifier = nltk.NaiveBayesClassifier.train(training_set)

# %%
# dftest is a dataframe containing all the test tweets
dftest = pd.read_csv("/home/ashish/Desktop/FDP_CIT/Python code SA/testdata.csv", encoding ="ISO-8859-1")

# %%
# Use the Naive Bayes Classifier and find the sentiment of test tweets
pred= dftest['text'].apply(lambda tweet: NBClassifier.classify(extract_features(getFeatureVector(processTweet2(tweet)))))

# %%
def getAccuracy(testSet, predictions):
	correct = 0
	for i in range(len(testSet)):
		if testSet[i]== predictions[i]:
			correct += 1
	return (correct/float(len(testSet))) * 100.0

# %%
org=dftest['class']
accuracy = getAccuracy(org, pred)

# %%
print('Accuracy: {0}%'.format(accuracy))
# Out:
# Accuracy: 93.18181818181817%
